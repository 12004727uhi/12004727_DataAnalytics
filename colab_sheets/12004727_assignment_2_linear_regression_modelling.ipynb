# %% [markdown]
# <a href="https://colab.research.google.com/github/12004727uhi/12004727_DataAnalytics/blob/master/colab_sheets/12004727_assignment_2_linear_regression_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas, to create data frame
import pandas as pd
# import numpy for maths operations
import numpy as np
# import tensorflow for modelling
# %tensorflow_version 1.x
import tensorflow as tf
# import file management utilities
import shutil
# import package to create data tables
from tabulate import tabulate
# import iterable tools
import itertools
# Out:
# TensorFlow 1.x selected.

# %%
## Configuration
#
# enable logging for tensorflow (set to ERROR when automating, or INFO for diagnostic)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# define dataset friendly title
DATASET_TITLE = '2013 to 2019 - Bronx County [linear_6.csv]'
# define dataset CSV URL
DATA_URL = 'https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/linear_6.csv'
# define validation dataset CSV URL
VALIDATION_DATA_URL = 'https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/sample_linear_6.csv'
# import dataset CSV & assign to variable (type pandas df)
TRAIN_AND_TEST_DATA = pd.read_csv(DATA_URL, index_col=0,)
# import validation dataset CSV & assign to variable (type pandas df)
VALIDATION_DATA = pd.read_csv(VALIDATION_DATA_URL, index_col=0,)
# define number of targets
NUM_TARGETS = 1
# define predictors for training/testing
predictor_column_list = [0,1,2,3,5,6,7]
predictors = []
for idx, predictor in enumerate(predictor_column_list, 1):
  predictors.append([list(p) for p in itertools.combinations(predictor_column_list, idx)])
  pred = [list(p) for p in itertools.combinations(predictor_column_list, idx)]
PREDICTORS_COLS = list(itertools.chain(*predictors))
# define target column indexes
TARGETS_COLS = [8]
# define validation target column name(s)
VALIDATION_TARGETS = ['NUM_COLLISIONS']
# URI of model
MODEL_URI = '/tmp/linear_trained_model'
# define how many model runs for training & testing
NUMBER_OF_TRAIN_TEST_RUNS = 5
# define how many model runs for validation
NUMBER_OF_VALIDATION_RUNS = 5
# Define scale parameter for number of collisions
SCALE_NUM_COLLISIONS = 1.0
# define number of estimator fit steps
ESTIMATOR_STEPS = 10000
# set training set size (percentage as decimal)
TRAINING_SET_SLICE = 0.8

# show first 5 rows to verify import
display(TRAIN_AND_TEST_DATA[:5])
# show first 5 rows to verify import
display(VALIDATION_DATA[:5])
# print length of predictors column list to verify
print(f'Predictors columns: {len(PREDICTORS_COLS)}')
# check the tensorflow version
print(f'Tensor flow version: {tf.__version__}')
# Out:
#      day_index  day  year  mo        county  temp  visib  wdsp  NUM_COLLISIONS
# 375          5    2  2013   1  Bronx County  38.0   10.0  15.0        0.127193
# 382          7    3  2013   1  Bronx County  27.5   10.0  12.4        0.232456
# 395         15    4  2013   1  Bronx County  21.8   10.0   9.8        0.258772
# 401         16    5  2013   1  Bronx County  32.2   10.0  11.3        0.241228
# 411         21    6  2013   1  Bronx County  37.3   10.0  13.2        0.171053
#        day_index  day  year  mo  ...  temp  visib  wdsp  NUM_COLLISIONS
# 4602        2388    2  2019   4  ...  48.8    6.3  11.4        0.648069
# 1238         493    7  2014   1  ...  26.8    9.4  17.8        0.470874
# 176         1597    6  2017   1  ...  38.7   10.0  18.3        0.585153
# 15242       1193    2  2016  11  ...  47.2   10.0   7.1        0.691983
# 1739         939    3  2015   2  ...  32.6    9.9  23.9        0.647321
#
# [5 rows x 9 columns]
# Predictors columns: 127
# Tensor flow version: 1.15.2

# %%
# function to loop linear regressor n times (shuffling data each time). Returns dict of RMSE results.
def run_linear_regressor(predictors_cols):
  # define result list to return
  result_list = []
  for idx, run in enumerate(range(NUMBER_OF_TRAIN_TEST_RUNS)):
    # shuffle data & print first 5 rows
    shuffled = TRAIN_AND_TEST_DATA.iloc[np.random.permutation(len(TRAIN_AND_TEST_DATA))]
    # assign predictors to variable
    predictors = shuffled.iloc[:,predictors_cols]
    # assign targets to variable
    targets = shuffled.iloc[:,TARGETS_COLS]
    # define training set size - 80% of the shuffled data array length
    training_set_size = int(len(shuffled['NUM_COLLISIONS'])*TRAINING_SET_SLICE)
    # define test set size - the remaining of the shuffled data array length
    test_set_size = len(shuffled['NUM_COLLISIONS']) - training_set_size
    # Define number of targets (outputs)
    num_of_targets = NUM_TARGETS
    # ensure any previously saved training run models are removed
    shutil.rmtree(MODEL_URI, ignore_errors=True)
    # define the TensorFlow estimator
    estimator = tf.contrib.learn.SKCompat(
        tf.contrib.learn.LinearRegressor(
            model_dir=MODEL_URI, 
            optimizer=tf.train.AdamOptimizer(learning_rate=0.1), 
            enable_centered_bias=False, 
            feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors.values) 
            )
        )
    # train the model, using previously defined predictor & target values
    estimator.fit(predictors[:training_set_size].values, 
                  targets[:training_set_size].values.reshape(
                      training_set_size, num_of_targets)/SCALE_NUM_COLLISIONS, steps=ESTIMATOR_STEPS
                  )
    # check predictions based on defined predictors and assign result to variable
    predictions = estimator.predict(x=predictors[training_set_size:].values)
    # Apply scaling to output (not require here as previously discussed)
    predictions_scaled = predictions['scores']*SCALE_NUM_COLLISIONS
    # format predictions as strings to make readable in printing to check output etc
    predictions_formatted = format(str(predictions_scaled))
    # calculate RSME to determine how well the model is predicting the targets from the predictors
    rmse_linear_model = np.sqrt(np.mean((targets[training_set_size:].values - predictions_scaled)**2))
    # calculate mean of the normalised collision values
    mean_norm_collisions = np.mean(shuffled['NUM_COLLISIONS'][:training_set_size])
    # calculate the RMSE of line of best fit that simply follows a mean of target values.
    # This allows comparison between the 'mean model' and the proposed linear regression model.
    # If the linear regression model is successful, it will show a 'better fit' than the 'mean model'
    # i.e., the resulting calculation should be *lower*.
    rmse_mean_model = np.sqrt(np.mean((shuffled['NUM_COLLISIONS'][training_set_size:] - mean_norm_collisions)**2))
    # add rmse calculations to result list
    result_list.append({'Run': idx+1, 'Linear Regression Model RMSE': rmse_linear_model, 'Mean Model RMSE': rmse_mean_model, 'Predictors Columns': predictors_cols})
  return result_list

# %%
## validate against normalised, processed dataset
# set pandas to display _all_ columns
pd.set_option('display.max_columns', None)
def run_validation(validation_predictors_cols):
  # define rmse results list
  validation_rmse_result_list = []
  for idx, run in enumerate(range(NUMBER_OF_VALIDATION_RUNS)):
    # shuffle data
    shuffled_validation_data = VALIDATION_DATA.iloc[np.random.permutation(len(VALIDATION_DATA))]
    # assign predictors to variables
    predictors_validation_data = shuffled_validation_data.iloc[:,validation_predictors_cols]
    # define TensorFlow estimator
    estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.LinearRegressor(model_dir=MODEL_URI, enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors_validation_data.values)))
    # check predictions based on defined predictors and assign result to variable
    validation_predictions = estimator.predict(x=predictors_validation_data.values)
    # extract a list of the resulting prediction scores
    validation_prediction_scores = validation_predictions['scores']
    # define validation data targets
    targets_validation = pd.DataFrame(list(VALIDATION_DATA[t] for t in VALIDATION_TARGETS))
    # calculate RMSE for regression model and actual validation collision data
    rmse_validation = np.sqrt(np.mean((targets_validation.values - validation_prediction_scores)**2))
    # add RMSE to list
    validation_rmse_result_list.append({'Run': idx+1, 'Validation Test RMSE': rmse_validation, 'Predictors Columns': validation_predictors_cols})
  # return  result list
  return validation_rmse_result_list

# %%
# function to create table of training/testing results & compute RSME
def create_table(rmse_results):
  # calculate mean & median RMSEs
  regression_RMSE_list = [n['Linear Regression Model RMSE'] for n in rmse_results]
  mean_model_RMSE_list = [n['Mean Model RMSE'] for n in rmse_results]
  regression_mean_RMSE = np.mean(regression_RMSE_list)
  mean_mean_RMSE = np.mean(mean_model_RMSE_list)
  regression_median_RMSE = np.median(regression_RMSE_list)
  mean_median_RMSE = np.median(mean_model_RMSE_list)
  header = rmse_results[0].keys()
  rows =  [x.values() for x in rmse_results]
  # ONLY PRINT OUTPUT IF regression_median_RMSE <= 1.0
  if regression_median_RMSE < 1.0:
    print(tabulate(rows, header, floatfmt=".15"))
    # print mean & median RMSEs
    print(f'\nMean RMSE for "Linear Regression Model": {regression_mean_RMSE}')
    print(f'Median RMSE for "Linear Regression Model": {regression_median_RMSE}')
    print(f'Mean RMSE for "Mean Model": {mean_mean_RMSE}')
    print(f'Median RMSE for "Mean Model": {mean_median_RMSE}\n')
    return True
  else:
    print(f'Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.')
    return False

# %%
# function to create table of validation results & compute RSME
def create_validation_table(validation_results):
  header = validation_results[0].keys()
  rows =  [x.values() for x in validation_results]
  # print table
  print(tabulate(rows, header, floatfmt=".15"))
  # calculate mean & median RMSEs
  validation_RMSE_list = [n['Validation Test RMSE'] for n in validation_results]
  validation_mean_RMSE = np.mean(validation_RMSE_list)
  validation_median_RMSE = np.median(validation_RMSE_list)
  # print mean & median RMSEs
  print(f'\nMean RMSE for Validaton Data: {validation_mean_RMSE}')
  print(f'Median RMSE for Validaton Data: {validation_median_RMSE}')

# %%
# function to generate rank table of median rmse result over n runs
def create_rank_table(all_results):
  # define final table lists
  table_list = []
  # compile table list with medians 
  for model in all_results:
    run_rmse_list = [run['Linear Regression Model RMSE'] for run in model['model_results']]
    run_mean_model_rmse_list = [run['Mean Model RMSE'] for run in model['model_results']]
    run_validation_rmse_list = [run['Validation Test RMSE'] for run in model['validation_results']]
    table_list.append({'Median RMSE\n(Ranked)': np.median(run_rmse_list), 
                       'Median \'Mean Model\'\nRMSE': np.median(run_mean_model_rmse_list),
                       'Model\nPredictors': '\n'.join([TRAIN_AND_TEST_DATA.columns[c] for c in model['model_results'][0]['Predictors Columns']]),
                       'Model\nRuns': len(run_rmse_list),
                       'Median Validation\nRMSE': np.median(run_validation_rmse_list),
                       'Validation\nRuns': len(run_validation_rmse_list)
                       })
  # rank medians
  sorted_table_list = sorted(table_list, key=lambda d: d['Median RMSE\n(Ranked)'])
  # display table
  print('\n----------------------------------------------------------------')
  print('Ranked Table of Median RMSE Results for Linear Regression Models')
  print('----------------------------------------------------------------')
  print('Tensor Flow Linear Regression Output')
  print(f'Model dataset title: {DATASET_TITLE}')
  print(f'Model dataset CSV: {DATA_URL}')
  print(f'Model validation dataset CSV: {VALIDATION_DATA_URL}\n')
  header = sorted_table_list[0].keys()
  rows =  [x.values() for x in sorted_table_list]
  print(tabulate(rows, header, floatfmt=".15", showindex='always', tablefmt="grid"))

# %%
# - run all models n times, for all predictor combinations on imported datasets;
# - calculate & tabulate RMSEs for each model run & then calculate mean RMSE;
# - run model n time on validation datasets, for all predictor combinations;
# - calculate RMSE for each model validation run & then calculate mean RMSE;

# function to do modelling & validation
def model_and_validate():
  # define list to retain all results in memory for further analysis if necessary
  all_rmse_results = []
  # print sheet header
  print(f'Tensor Flow Linear Regression Output')
  print(f'Model dataset title: {DATASET_TITLE}')
  print(f'Model dataset CSV: {DATA_URL}')
  print(f'Model validation dataset CSV: {VALIDATION_DATA_URL}')
  print(f'------------------------------------------------------------------------------\n')
  for predictors_combination in PREDICTORS_COLS:
    # print the predictor combination
    print('Model for these predictors: {}'.format(", ".join(f"\'{TRAIN_AND_TEST_DATA.columns[c]}\'" for c in predictors_combination)))
    print('Model for these targets: {}\n'.format(", ".join(f"\'{TRAIN_AND_TEST_DATA.columns[t]}\'" for t in TARGETS_COLS)))
    rmse_result_list = run_linear_regressor(predictors_combination)
    # draw table
    model_table_generated = gen_results_table(rmse_result_list)
    # perform validation process
    validation_rmse_result_list = do_validation(predictors_combination, draw_table=model_table_generated)
     # add results to in-memory list
    all_rmse_results.append({'model_results': rmse_result_list, 'validation_results': validation_rmse_result_list})
    print(f'\n-------\n')
  # generate rank table of median rmse result over n runs
  generate_rank_table(all_rmse_results)
  return all_rmse_results

# function to do validation
def do_validation(predictors_combination, draw_table):
  validation_result_list = run_validation(predictors_combination)
  # draw results table only if model table was also drawn
  if draw_table:
    print('Validate for these predictors: {}'.format(", ".join(f"\'{VALIDATION_DATA.columns[c]}\'" for c in predictors_combination)))
    print('Validate for these targets: {}\n'.format(", ".join(f"\'{t}\'" for t in VALIDATION_TARGETS)))
    gen_validation_results_table(validation_result_list)
  return validation_result_list

# function to generate table of results
def gen_results_table(rmse_result_list):
  return create_table(rmse_result_list)

# function to generate rank table of results
def generate_rank_table(all_results):
  create_rank_table(all_results)

# function to generate table of validation results
def gen_validation_results_table(validation_result_list):
  create_validation_table(validation_result_list)
  
all_rmse_results = model_and_validate()
# Out:
# Tensor Flow Linear Regression Output
# Model dataset title: 2013 to 2019 - Bronx County [linear_6.csv]
# Model dataset CSV: https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/linear_6.csv
# Model validation dataset CSV: https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/sample_linear_6.csv
# ------------------------------------------------------------------------------
#
# Model for these predictors: 'day_index'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.405418250997235  0.206037370102812  [0]
#     2               2.64021583078619   0.204155735407123  [0]
#     3               0.299587836117557  0.204496311688705  [0]
#     4               3.30163929439023   0.204396191667258  [0]
#     5               0.346764666501861  0.204752453202807  [0]
#
# Mean RMSE for "Linear Regression Model": 1.3987251757586137
# Median RMSE for "Linear Regression Model": 0.4054182509972351
# Mean RMSE for "Mean Model": 0.20476761241374083
# Median RMSE for "Mean Model": 0.20449631168870477
#
# Validate for these predictors: 'day_index'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.304838458147549  [0]
#     2       0.277544167319956  [0]
#     3       0.293929303476073  [0]
#     4       0.245271191773162  [0]
#     5       0.256916805278125  [0]
#
# Mean RMSE for Validaton Data: 0.27569998519897304
# Median RMSE for Validaton Data: 0.27754416731995557
#
# -------
#
# Model for these predictors: 'day'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.204077302625178  0.203069952610816  [1]
#     2               0.204703554363611  0.199522568014477  [1]
#     3               0.208131939767707  0.204811121013996  [1]
#     4               0.202097664875778  0.201002980516121  [1]
#     5               0.207658533729674  0.201103030925763  [1]
#
# Mean RMSE for "Linear Regression Model": 0.20533379907238958
# Median RMSE for "Linear Regression Model": 0.20470355436361143
# Mean RMSE for "Mean Model": 0.20190193061623454
# Median RMSE for "Mean Model": 0.20110303092576337
#
# Validate for these predictors: 'day'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.143176556752881  [1]
#     2       0.168073500722377  [1]
#     3       0.134631998229571  [1]
#     4       0.15233720888357   [1]
#     5       0.166172557687807  [1]
#
# Mean RMSE for Validaton Data: 0.15287836445524153
# Median RMSE for Validaton Data: 0.15233720888357047
#
# -------
#
# Model for these predictors: 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.206879549379047  0.203284954059619  [3]
#     2               0.20402695030824   0.199393444275981  [3]
#     3               0.210139395488371  0.201046731896679  [3]
#     4               0.202660258868746  0.200161741401447  [3]
#     5               0.224505371898098  0.203791736130797  [3]
#
# Mean RMSE for "Linear Regression Model": 0.20964230518850036
# Median RMSE for "Linear Regression Model": 0.2068795493790472
# Mean RMSE for "Mean Model": 0.20153572155290472
# Median RMSE for "Mean Model": 0.20104673189667926
#
# Validate for these predictors: 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.181202771249905  [3]
#     2       0.175764825410278  [3]
#     3       0.156622647778815  [3]
#     4       0.177375185198909  [3]
#     5       0.182443767086209  [3]
#
# Mean RMSE for Validaton Data: 0.17468183934482315
# Median RMSE for Validaton Data: 0.17737518519890902
#
# -------
#
# Model for these predictors: 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.205164870506327  0.203642413775708  [5]
#     2               0.319251852131882  0.201022290513373  [5]
#     3               0.206007508766073  0.20405127486091   [5]
#     4               0.298163383850233  0.203002609697175  [5]
#     5               0.259038327460885  0.204518656613546  [5]
#
# Mean RMSE for "Linear Regression Model": 0.2575251885430798
# Median RMSE for "Linear Regression Model": 0.25903832746088545
# Mean RMSE for "Mean Model": 0.20324744909214223
# Median RMSE for "Mean Model": 0.20364241377570813
#
# Validate for these predictors: 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.193875698958728  [5]
#     2       0.188846627811069  [5]
#     3       0.185341701154342  [5]
#     4       0.219710495622457  [5]
#     5       0.195831452703163  [5]
#
# Mean RMSE for Validaton Data: 0.19672119524995194
# Median RMSE for Validaton Data: 0.19387569895872836
#
# -------
#
# Model for these predictors: 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.202176176664572  0.200631397767201  [6]
#     2               0.210603295010835  0.201509157165395  [6]
#     3               0.207010427141271  0.207000096918674  [6]
#     4               0.202519129184301  0.201643436316042  [6]
#     5               0.214744682973782  0.203236891356876  [6]
#
# Mean RMSE for "Linear Regression Model": 0.20741074219495212
# Median RMSE for "Linear Regression Model": 0.2070104271412708
# Mean RMSE for "Mean Model": 0.20280419590483753
# Median RMSE for "Mean Model": 0.2016434363160421
#
# Validate for these predictors: 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.159117880199202  [6]
#     2       0.162065092258974  [6]
#     3       0.167720608453683  [6]
#     4       0.154959782725255  [6]
#     5       0.15877654545152   [6]
#
# Mean RMSE for Validaton Data: 0.16052798181772682
# Median RMSE for Validaton Data: 0.15911788019920192
#
# -------
#
# Model for these predictors: 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.215075682462059  0.20329080248728   [7]
#     2               0.203063525753209  0.202245157292918  [7]
#     3               0.203565336728028  0.202888205179202  [7]
#     4               0.20366448764547   0.203333151406316  [7]
#     5               0.204454187966079  0.20429956568219   [7]
#
# Mean RMSE for "Linear Regression Model": 0.20596464411096904
# Median RMSE for "Linear Regression Model": 0.2036644876454704
# Mean RMSE for "Mean Model": 0.20321137640958103
# Median RMSE for "Mean Model": 0.2032908024872803
#
# Validate for these predictors: 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.146324626943232  [7]
#     2       0.142356789440447  [7]
#     3       0.141807065591799  [7]
#     4       0.1444349258494    [7]
#     5       0.147287240979247  [7]
#
# Mean RMSE for Validaton Data: 0.14444212976082502
# Median RMSE for Validaton Data: 0.14443492584940038
#
# -------
#
# Model for these predictors: 'day_index', 'day'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.739787796342528  0.204592785355174  [0, 1]
#     2               0.849001823199689  0.202650663938921  [0, 1]
#     3               0.297916497629541  0.205287699840118  [0, 1]
#     4               0.271581927527624  0.201823922486597  [0, 1]
#     5               0.655470927076783  0.204364915429395  [0, 1]
#
# Mean RMSE for "Linear Regression Model": 0.5627517943552329
# Median RMSE for "Linear Regression Model": 0.655470927076783
# Mean RMSE for "Mean Model": 0.20374399741004093
# Median RMSE for "Mean Model": 0.20436491542939458
#
# Validate for these predictors: 'day_index', 'day'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.543161693148788  [0, 1]
#     2       0.577334920555087  [0, 1]
#     3       0.542490533226172  [0, 1]
#     4       0.544212994919887  [0, 1]
#     5       0.613583943970651  [0, 1]
#
# Mean RMSE for Validaton Data: 0.564156817164117
# Median RMSE for Validaton Data: 0.544212994919887
#
# -------
#
# Model for these predictors: 'day_index', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.250149814137792  0.20609853459861   [0, 3]
#     2               0.294539700871725  0.203473442631057  [0, 3]
#     3               0.230186719949485  0.204231055566259  [0, 3]
#     4               0.219179161112357  0.203382779844447  [0, 3]
#     5               9.70266379861408   0.202969856610054  [0, 3]
#
# Mean RMSE for "Linear Regression Model": 2.139343838937088
# Median RMSE for "Linear Regression Model": 0.25014981413779186
# Mean RMSE for "Mean Model": 0.2040311338500854
# Median RMSE for "Mean Model": 0.2034734426310573
#
# Validate for these predictors: 'day_index', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1        8.21093247979966  [0, 3]
#     2        8.19075054454831  [0, 3]
#     3        8.23034696227545  [0, 3]
#     4        8.22793159497185  [0, 3]
#     5        8.17515724922431  [0, 3]
#
# Mean RMSE for Validaton Data: 8.207023766163918
# Median RMSE for Validaton Data: 8.210932479799663
#
# -------
#
# Model for these predictors: 'day_index', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               1.33310013543584   0.202215694837508  [0, 5]
#     2               0.708729868910507  0.2002647710114    [0, 5]
#     3               0.245157224248874  0.203251757960407  [0, 5]
#     4               3.91475109048756   0.20261231594721   [0, 5]
#     5               0.29989085746089   0.204326730174056  [0, 5]
#
# Mean RMSE for "Linear Regression Model": 1.3003258353087355
# Median RMSE for "Linear Regression Model": 0.7087298689105067
# Mean RMSE for "Mean Model": 0.202534253986116
# Median RMSE for "Mean Model": 0.20261231594720952
#
# Validate for these predictors: 'day_index', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.222123099713618  [0, 5]
#     2       0.189851287460011  [0, 5]
#     3       0.252419999913215  [0, 5]
#     4       0.253151517541713  [0, 5]
#     5       0.237882993833686  [0, 5]
#
# Mean RMSE for Validaton Data: 0.2310857796924485
# Median RMSE for Validaton Data: 0.23788299383368622
#
# -------
#
# Model for these predictors: 'day_index', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.238608991798889  0.20348924869514   [0, 6]
#     2               0.423820549400717  0.203277989282569  [0, 6]
#     3               0.205506884170838  0.203453877594027  [0, 6]
#     4               1.03601868323336   0.202089504546449  [0, 6]
#     5               0.210922192243167  0.202043470800074  [0, 6]
#
# Mean RMSE for "Linear Regression Model": 0.4229754601693946
# Median RMSE for "Linear Regression Model": 0.23860899179888923
# Mean RMSE for "Mean Model": 0.20287081818365182
# Median RMSE for "Mean Model": 0.20327798928256885
#
# Validate for these predictors: 'day_index', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.12767524528538   [0, 6]
#     2       0.14442938835667   [0, 6]
#     3       0.143867136236896  [0, 6]
#     4       0.153241785865599  [0, 6]
#     5       0.148366715936572  [0, 6]
#
# Mean RMSE for Validaton Data: 0.14351605433622341
# Median RMSE for Validaton Data: 0.14442938835666985
#
# -------
#
# Model for these predictors: 'day_index', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.212055750944415  0.206507031478487  [0, 7]
#     2              17.4846300584801    0.201584213358754  [0, 7]
#     3               0.736610951544185  0.20551881214089   [0, 7]
#     4               4.8847928574968    0.206141132353667  [0, 7]
#     5               0.282118132844574  0.200467594301653  [0, 7]
#
# Mean RMSE for "Linear Regression Model": 4.720041550262014
# Median RMSE for "Linear Regression Model": 0.7366109515441854
# Mean RMSE for "Mean Model": 0.2040437567266903
# Median RMSE for "Mean Model": 0.2055188121408903
#
# Validate for these predictors: 'day_index', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.220823568145898  [0, 7]
#     2       0.228274161439657  [0, 7]
#     3       0.203743621139936  [0, 7]
#     4       0.190537676560626  [0, 7]
#     5       0.246305930085868  [0, 7]
#
# Mean RMSE for Validaton Data: 0.21793699147439693
# Median RMSE for Validaton Data: 0.22082356814589776
#
# -------
#
# Model for these predictors: 'day', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.207123074977791  0.202158011457725  [1, 3]
#     2               0.224130437837223  0.200191698200781  [1, 3]
#     3               0.254754970387251  0.204638674401801  [1, 3]
#     4               0.232854186697236  0.202285163705517  [1, 3]
#     5               0.264617782292822  0.202339337872628  [1, 3]
#
# Mean RMSE for "Linear Regression Model": 0.2366960904384645
# Median RMSE for "Linear Regression Model": 0.2328541866972356
# Mean RMSE for "Mean Model": 0.2023225771276905
# Median RMSE for "Mean Model": 0.20228516370551697
#
# Validate for these predictors: 'day', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.238990629797726  [1, 3]
#     2       0.197855482073382  [1, 3]
#     3       0.21346554262204   [1, 3]
#     4       0.159251776104051  [1, 3]
#     5       0.208561720358115  [1, 3]
#
# Mean RMSE for Validaton Data: 0.20362503019106287
# Median RMSE for Validaton Data: 0.2085617203581146
#
# -------
#
# Model for these predictors: 'day', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.350040534296905  0.203469642471724  [1, 5]
#     2               0.205730590113305  0.202906055396948  [1, 5]
#     3               0.205737582463539  0.200589556949844  [1, 5]
#     4               0.23215410543462   0.206553209588749  [1, 5]
#     5               0.203619834044213  0.19979860850795   [1, 5]
#
# Mean RMSE for "Linear Regression Model": 0.23945652927051633
# Median RMSE for "Linear Regression Model": 0.20573758246353901
# Mean RMSE for "Mean Model": 0.2026634145830432
# Median RMSE for "Mean Model": 0.20290605539694823
#
# Validate for these predictors: 'day', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.158849480158881  [1, 5]
#     2       0.141286700824618  [1, 5]
#     3       0.171977385790648  [1, 5]
#     4       0.148390780692088  [1, 5]
#     5       0.161198320329296  [1, 5]
#
# Mean RMSE for Validaton Data: 0.1563405335591061
# Median RMSE for Validaton Data: 0.1588494801588813
#
# -------
#
# Model for these predictors: 'day', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.208297261125296  0.2032169066197    [1, 6]
#     2               0.215770320299893  0.204088181680405  [1, 6]
#     3               0.23379365909123   0.205734701196331  [1, 6]
#     4               0.214341878583407  0.203705612543125  [1, 6]
#     5               0.210252448680182  0.204903629538522  [1, 6]
#
# Mean RMSE for "Linear Regression Model": 0.21649111355600154
# Median RMSE for "Linear Regression Model": 0.21434187858340667
# Mean RMSE for "Mean Model": 0.20432980631561665
# Median RMSE for "Mean Model": 0.20408818168040488
#
# Validate for these predictors: 'day', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.151649167167527  [1, 6]
#     2       0.166455320403904  [1, 6]
#     3       0.138594941517432  [1, 6]
#     4       0.150382697424082  [1, 6]
#     5       0.164778737440467  [1, 6]
#
# Mean RMSE for Validaton Data: 0.15437217279068244
# Median RMSE for Validaton Data: 0.1516491671675271
#
# -------
#
# Model for these predictors: 'day', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.232711411662747  0.204018224979151  [1, 7]
#     2               0.23205572973395   0.203385139050361  [1, 7]
#     3               0.224513815527488  0.205867423211676  [1, 7]
#     4               0.235252508212808  0.207467133969837  [1, 7]
#     5               0.211537294268639  0.20468862287      [1, 7]
#
# Mean RMSE for "Linear Regression Model": 0.22721415188112631
# Median RMSE for "Linear Regression Model": 0.2320557297339502
# Mean RMSE for "Mean Model": 0.20508530881620488
# Median RMSE for "Mean Model": 0.20468862286999984
#
# Validate for these predictors: 'day', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.147007919827276  [1, 7]
#     2       0.158170555354911  [1, 7]
#     3       0.134514009822093  [1, 7]
#     4       0.149113032390172  [1, 7]
#     5       0.161192600130667  [1, 7]
#
# Mean RMSE for Validaton Data: 0.1499996235050235
# Median RMSE for Validaton Data: 0.14911303239017154
#
# -------
#
# Model for these predictors: 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.350317287813723  0.198829533496999  [3, 5]
#     2               0.210386984794472  0.204295482115161  [3, 5]
#     3               0.441956429724072  0.203638558128909  [3, 5]
#     4               0.247505758649571  0.204201147179114  [3, 5]
#     5               0.31200094084227   0.204002870687021  [3, 5]
#
# Mean RMSE for "Linear Regression Model": 0.3124334803648214
# Median RMSE for "Linear Regression Model": 0.3120009408422696
# Mean RMSE for "Mean Model": 0.20299351832144072
# Median RMSE for "Mean Model": 0.20400287068702108
#
# Validate for these predictors: 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.250567717460356  [3, 5]
#     2       0.261637282537626  [3, 5]
#     3       0.253001351764223  [3, 5]
#     4       0.269152280578528  [3, 5]
#     5       0.231700488390141  [3, 5]
#
# Mean RMSE for Validaton Data: 0.25321182414617494
# Median RMSE for Validaton Data: 0.2530013517642227
#
# -------
#
# Model for these predictors: 'mo', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.26653286676144   0.203836074207949  [3, 6]
#     2               0.207965814703869  0.204914433533926  [3, 6]
#     3               0.203560169338376  0.202928994264082  [3, 6]
#     4               0.206462429473623  0.202405734642942  [3, 6]
#     5               0.217169892503711  0.203735397973148  [3, 6]
#
# Mean RMSE for "Linear Regression Model": 0.22033823455620372
# Median RMSE for "Linear Regression Model": 0.20796581470386907
# Mean RMSE for "Mean Model": 0.20356412692440942
# Median RMSE for "Mean Model": 0.20373539797314816
#
# Validate for these predictors: 'mo', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.143122924311718  [3, 6]
#     2       0.166439158935854  [3, 6]
#     3       0.154214577815085  [3, 6]
#     4       0.145923050648815  [3, 6]
#     5       0.160610210721272  [3, 6]
#
# Mean RMSE for Validaton Data: 0.15406198448654873
# Median RMSE for Validaton Data: 0.15421457781508505
#
# -------
#
# Model for these predictors: 'mo', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.238346630754809  0.20440295552523   [3, 7]
#     2               0.209552936124383  0.205401432320295  [3, 7]
#     3               0.20962311105486   0.20813642813197   [3, 7]
#     4               0.229077817237079  0.204346205455977  [3, 7]
#     5               0.209990309047132  0.203692950387557  [3, 7]
#
# Mean RMSE for "Linear Regression Model": 0.2193181608436527
# Median RMSE for "Linear Regression Model": 0.2099903090471319
# Mean RMSE for "Mean Model": 0.2051959943642058
# Median RMSE for "Mean Model": 0.20440295552523036
#
# Validate for these predictors: 'mo', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.154154371536307  [3, 7]
#     2       0.16764889158397   [3, 7]
#     3       0.160571995047751  [3, 7]
#     4       0.169271915248258  [3, 7]
#     5       0.135225595450318  [3, 7]
#
# Mean RMSE for Validaton Data: 0.1573745537733207
# Median RMSE for Validaton Data: 0.16057199504775121
#
# -------
#
# Model for these predictors: 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.218431108598877  0.202627157630725  [5, 6]
#     2               0.241323479234087  0.201361041298626  [5, 6]
#     3               0.342842320759073  0.202479331983793  [5, 6]
#     4               0.208992139650376  0.20609361747672   [5, 6]
#     5               0.203552360490802  0.203311627355162  [5, 6]
#
# Mean RMSE for "Linear Regression Model": 0.24302828174664276
# Median RMSE for "Linear Regression Model": 0.21843110859887685
# Mean RMSE for "Mean Model": 0.20317455514900534
# Median RMSE for "Mean Model": 0.20262715763072459
#
# Validate for these predictors: 'temp', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.143898808091424  [5, 6]
#     2       0.143039264623362  [5, 6]
#     3       0.136821966080565  [5, 6]
#     4       0.144847587049634  [5, 6]
#     5       0.144205289546169  [5, 6]
#
# Mean RMSE for Validaton Data: 0.1425625830782308
# Median RMSE for Validaton Data: 0.14389880809142389
#
# -------
#
# Model for these predictors: 'temp', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.292417858102616  0.201141862181134  [5, 7]
#     2               0.226274660456256  0.200227857213377  [5, 7]
#     3               0.210579036870745  0.202392016971549  [5, 7]
#     4               0.339873800681312  0.203443092724322  [5, 7]
#     5               0.243302746957275  0.200439837274619  [5, 7]
#
# Mean RMSE for "Linear Regression Model": 0.26248962061364073
# Median RMSE for "Linear Regression Model": 0.24330274695727494
# Mean RMSE for "Mean Model": 0.20152893327300014
# Median RMSE for "Mean Model": 0.20114186218113397
#
# Validate for these predictors: 'temp', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.199292187075389  [5, 7]
#     2       0.199922026555364  [5, 7]
#     3       0.200421892296176  [5, 7]
#     4       0.199908734090107  [5, 7]
#     5       0.19934188307614   [5, 7]
#
# Mean RMSE for Validaton Data: 0.19977734461863522
# Median RMSE for Validaton Data: 0.199908734090107
#
# -------
#
# Model for these predictors: 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.204765108157729  0.202754877727873  [6, 7]
#     2               0.216356679955151  0.202442015207083  [6, 7]
#     3               0.202581564372371  0.201968852994006  [6, 7]
#     4               0.205467299543064  0.203947196764847  [6, 7]
#     5               0.208097266644491  0.201286754205964  [6, 7]
#
# Mean RMSE for "Linear Regression Model": 0.20745358373456124
# Median RMSE for "Linear Regression Model": 0.20546729954306425
# Mean RMSE for "Mean Model": 0.20247993937995465
# Median RMSE for "Mean Model": 0.20244201520708338
#
# Validate for these predictors: 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.150834683862348  [6, 7]
#     2       0.147716156087541  [6, 7]
#     3       0.148872385319452  [6, 7]
#     4       0.151741342513563  [6, 7]
#     5       0.145037033279823  [6, 7]
#
# Mean RMSE for Validaton Data: 0.14884032021254523
# Median RMSE for Validaton Data: 0.14887238531945166
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.651821060096393  0.202138605304243  [0, 1, 2]
#     2               0.206094621668628  0.20377499763778   [0, 1, 2]
#     3               0.500184512110309  0.201696170876247  [0, 1, 2]
#     4              28.194098684747     0.202082346570813  [0, 1, 2]
#     5               1.91639772375721   0.201599901825564  [0, 1, 2]
#
# Mean RMSE for "Linear Regression Model": 6.293719320475908
# Median RMSE for "Linear Regression Model": 0.6518210600963931
# Mean RMSE for "Mean Model": 0.20225840444292933
# Median RMSE for "Mean Model": 0.20208234657081273
#
# Validate for these predictors: 'day_index', 'day', 'year'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1        1.80162043371775  [0, 1, 2]
#     2        1.79380848028165  [0, 1, 2]
#     3        1.81089567036558  [0, 1, 2]
#     4        1.8030902183072   [0, 1, 2]
#     5        1.79499210051585  [0, 1, 2]
#
# Mean RMSE for Validaton Data: 1.800881380637606
# Median RMSE for Validaton Data: 1.8016204337177468
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.496575519933375  0.205502362269372  [0, 1, 3]
#     2               0.655576243384465  0.204404500446851  [0, 1, 3]
#     3               0.406800618373647  0.207272045172455  [0, 1, 3]
#     4               7.34645796181874   0.20695354525598   [0, 1, 3]
#     5               0.38591072583615   0.204107025633804  [0, 1, 3]
#
# Mean RMSE for "Linear Regression Model": 1.8582642138692755
# Median RMSE for "Linear Regression Model": 0.49657551993337534
# Mean RMSE for "Mean Model": 0.2056478957556925
# Median RMSE for "Mean Model": 0.20550236226937213
#
# Validate for these predictors: 'day_index', 'day', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.28218999998269   [0, 1, 3]
#     2       0.303495176838222  [0, 1, 3]
#     3       0.295933354002459  [0, 1, 3]
#     4       0.294520732366814  [0, 1, 3]
#     5       0.27385517190222   [0, 1, 3]
#
# Mean RMSE for Validaton Data: 0.289998887018481
# Median RMSE for Validaton Data: 0.2945207323668142
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               7.88228558456251   0.203725605852714  [0, 1, 5]
#     2               0.214758433502273  0.205042217665491  [0, 1, 5]
#     3               0.410762108146263  0.207782054217617  [0, 1, 5]
#     4               0.364595846887797  0.201854772681303  [0, 1, 5]
#     5               1.5053268139216    0.203720496411113  [0, 1, 5]
#
# Mean RMSE for "Linear Regression Model": 2.075545757404087
# Median RMSE for "Linear Regression Model": 0.4107621081462626
# Mean RMSE for "Mean Model": 0.20442502936564746
# Median RMSE for "Mean Model": 0.2037256058527137
#
# Validate for these predictors: 'day_index', 'day', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1        1.33141488304973  [0, 1, 5]
#     2        1.36828114658455  [0, 1, 5]
#     3        1.36397174463888  [0, 1, 5]
#     4        1.36260993517013  [0, 1, 5]
#     5        1.35011647117147  [0, 1, 5]
#
# Mean RMSE for Validaton Data: 1.3552788361229513
# Median RMSE for Validaton Data: 1.3626099351701284
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.655358112940239  0.199858403537527  [0, 1, 7]
#     2               0.215324072715246  0.208638243897432  [0, 1, 7]
#     3               0.699403752260428  0.207454005169892  [0, 1, 7]
#     4               0.302622663255764  0.204172222405107  [0, 1, 7]
#     5               7.24312924815336   0.204213405850377  [0, 1, 7]
#
# Mean RMSE for "Linear Regression Model": 1.823167569865007
# Median RMSE for "Linear Regression Model": 0.6553581129402386
# Mean RMSE for "Mean Model": 0.2048672561720668
# Median RMSE for "Mean Model": 0.20421340585037664
#
# Validate for these predictors: 'day_index', 'day', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1        6.38247915707982  [0, 1, 7]
#     2        6.32360990900374  [0, 1, 7]
#     3        6.348997664081    [0, 1, 7]
#     4        6.34474488900935  [0, 1, 7]
#     5        6.37321997560296  [0, 1, 7]
#
# Mean RMSE for Validaton Data: 6.354610318955375
# Median RMSE for Validaton Data: 6.348997664081001
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.28149650910364   0.205325686208425  [0, 2, 3]
#     2               0.245226238897795  0.204980319734781  [0, 2, 3]
#     3               0.23955758283736   0.202376562037437  [0, 2, 3]
#     4               1.94516514662387   0.202660517130377  [0, 2, 3]
#     5               6.50316167893435   0.205835497580035  [0, 2, 3]
#
# Mean RMSE for "Linear Regression Model": 1.8429214312794049
# Median RMSE for "Linear Regression Model": 0.2814965091036404
# Mean RMSE for "Mean Model": 0.2042357165382108
# Median RMSE for "Mean Model": 0.20498031973478106
#
# Validate for these predictors: 'day_index', 'year', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1        5.99699618037974  [0, 2, 3]
#     2        5.99629666482763  [0, 2, 3]
#     3        5.99368833519898  [0, 2, 3]
#     4        6.0033978136296   [0, 2, 3]
#     5        5.99655946796743  [0, 2, 3]
#
# Mean RMSE for Validaton Data: 5.997387692400675
# Median RMSE for Validaton Data: 5.996559467967429
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.997413595703633  0.201550682760331  [0, 2, 5]
#     2               0.335870940696383  0.209639881056124  [0, 2, 5]
#     3               7.57246890746288   0.205951460980863  [0, 2, 5]
#     4               0.418571644446757  0.202927776033377  [0, 2, 5]
#     5               0.218100684981861  0.207458957337987  [0, 2, 5]
#
# Mean RMSE for "Linear Regression Model": 1.9084851546583022
# Median RMSE for "Linear Regression Model": 0.4185716444467575
# Mean RMSE for "Mean Model": 0.2055057516337365
# Median RMSE for "Mean Model": 0.20595146098086312
#
# Validate for these predictors: 'day_index', 'year', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.171038879738471  [0, 2, 5]
#     2       0.174373291718773  [0, 2, 5]
#     3       0.123445510274722  [0, 2, 5]
#     4       0.170610171055172  [0, 2, 5]
#     5       0.170017065721895  [0, 2, 5]
#
# Mean RMSE for Validaton Data: 0.16189698370180647
# Median RMSE for Validaton Data: 0.17061017105517234
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               9.55391329672303   0.206816377160287  [0, 2, 6]
#     2               0.801179620477275  0.204448659977391  [0, 2, 6]
#     3               0.208869833425313  0.203309907730267  [0, 2, 6]
#     4               0.377610245380384  0.204713503995543  [0, 2, 6]
#     5               0.450763634474396  0.204979534808962  [0, 2, 6]
#
# Mean RMSE for "Linear Regression Model": 2.2784673260960795
# Median RMSE for "Linear Regression Model": 0.45076363447439644
# Mean RMSE for "Mean Model": 0.20485359673449016
# Median RMSE for "Mean Model": 0.2047135039955431
#
# Validate for these predictors: 'day_index', 'year', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.373994129006166  [0, 2, 6]
#     2       0.384230368887577  [0, 2, 6]
#     3       0.402917954512928  [0, 2, 6]
#     4       0.413287073202396  [0, 2, 6]
#     5       0.369844735311613  [0, 2, 6]
#
# Mean RMSE for Validaton Data: 0.38885485218413585
# Median RMSE for Validaton Data: 0.38423036888757656
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.282169344061173  0.206587088747403  [0, 3, 5]
#     2               0.839013246247419  0.204080908401346  [0, 3, 5]
#     3               0.332554550953829  0.206284587881256  [0, 3, 5]
#     4               4.20825113545643   0.204007251447001  [0, 3, 5]
#     5               1.12098590977963   0.204914019288563  [0, 3, 5]
#
# Mean RMSE for "Linear Regression Model": 1.356594837299697
# Median RMSE for "Linear Regression Model": 0.8390132462474195
# Mean RMSE for "Mean Model": 0.20517477115311386
# Median RMSE for "Mean Model": 0.20491401928856282
#
# Validate for these predictors: 'day_index', 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       1.01679882807958   [0, 3, 5]
#     2       0.993671141563311  [0, 3, 5]
#     3       1.01515306375945   [0, 3, 5]
#     4       0.999128475580122  [0, 3, 5]
#     5       0.982293984967238  [0, 3, 5]
#
# Mean RMSE for Validaton Data: 1.00140909878994
# Median RMSE for Validaton Data: 0.9991284755801222
#
# -------
#
# Model for these predictors: 'day_index', 'mo', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               8.37220376836526   0.202230360647776  [0, 3, 6]
#     2               0.251847622940952  0.203916539078209  [0, 3, 6]
#     3               0.424348535375532  0.206750088985448  [0, 3, 6]
#     4               0.245392642966383  0.2020801903644    [0, 3, 6]
#     5              10.6657845265819    0.200087472749354  [0, 3, 6]
#
# Mean RMSE for "Linear Regression Model": 3.991915419246009
# Median RMSE for "Linear Regression Model": 0.4243485353755322
# Mean RMSE for "Mean Model": 0.2030129303650373
# Median RMSE for "Mean Model": 0.20223036064777583
#
# Validate for these predictors: 'day_index', 'mo', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1        8.97732326300455  [0, 3, 6]
#     2        9.01280547086112  [0, 3, 6]
#     3        9.01769717539589  [0, 3, 6]
#     4        9.01512181984429  [0, 3, 6]
#     5        9.0443925753569   [0, 3, 6]
#
# Mean RMSE for Validaton Data: 9.01346806089255
# Median RMSE for Validaton Data: 9.015121819844289
#
# -------
#
# Model for these predictors: 'day_index', 'mo', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.706196399604422  0.204696853075334  [0, 5, 6]
#     2               0.231525660945796  0.202091659229257  [0, 5, 6]
#     3               0.341505590797308  0.204128919291053  [0, 5, 6]
#     4              19.1329290667311    0.205080853722692  [0, 5, 6]
#     5               0.946863026527521  0.199967635527032  [0, 5, 6]
#
# Mean RMSE for "Linear Regression Model": 4.271803948921227
# Median RMSE for "Linear Regression Model": 0.7061963996044216
# Mean RMSE for "Mean Model": 0.20319318416907378
# Median RMSE for "Mean Model": 0.20412891929105345
#
# Validate for these predictors: 'day_index', 'temp', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.774319262044609  [0, 5, 6]
#     2       0.772241791056404  [0, 5, 6]
#     3       0.737546930689397  [0, 5, 6]
#     4       0.757977150773151  [0, 5, 6]
#     5       0.76045270904535   [0, 5, 6]
#
# Mean RMSE for Validaton Data: 0.760507568721782
# Median RMSE for Validaton Data: 0.76045270904535
#
# -------
#
# Model for these predictors: 'day_index', 'temp', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.213588188871789  0.200169830397084  [0, 5, 7]
#     2              15.8599735506461    0.205071698338222  [0, 5, 7]
#     3               6.05437411766151   0.202359314111742  [0, 5, 7]
#     4               0.284915757002597  0.200821135651215  [0, 5, 7]
#     5               0.21456125253186   0.201239655456876  [0, 5, 7]
#
# Mean RMSE for "Linear Regression Model": 4.525482573342767
# Median RMSE for "Linear Regression Model": 0.28491575700259725
# Mean RMSE for "Mean Model": 0.2019323267910277
# Median RMSE for "Mean Model": 0.20123965545687572
#
# Validate for these predictors: 'day_index', 'temp', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.17993634063573   [0, 5, 7]
#     2       0.15907165979308   [0, 5, 7]
#     3       0.163396440770776  [0, 5, 7]
#     4       0.161879161558926  [0, 5, 7]
#     5       0.161019640435069  [0, 5, 7]
#
# Mean RMSE for Validaton Data: 0.1650606486387163
# Median RMSE for Validaton Data: 0.1618791615589256
#
# -------
#
# Model for these predictors: 'day_index', 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.250992651566351  0.200763392940494  [0, 6, 7]
#     2               0.376421108567345  0.207843780435713  [0, 6, 7]
#     3               1.52676164847762   0.204354044208644  [0, 6, 7]
#     4               1.63384927841191   0.203717456910195  [0, 6, 7]
#     5               0.864528056089262  0.20240743333387   [0, 6, 7]
#
# Mean RMSE for "Linear Regression Model": 0.9305105486224985
# Median RMSE for "Linear Regression Model": 0.8645280560892618
# Mean RMSE for "Mean Model": 0.20381722156578302
# Median RMSE for "Mean Model": 0.20371745691019458
#
# Validate for these predictors: 'day_index', 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.730004693842104  [0, 6, 7]
#     2       0.663648123524854  [0, 6, 7]
#     3       0.683629946684913  [0, 6, 7]
#     4       0.609586128111332  [0, 6, 7]
#     5       0.68922877882201   [0, 6, 7]
#
# Mean RMSE for Validaton Data: 0.6752195341970424
# Median RMSE for Validaton Data: 0.6836299466849131
#
# -------
#
# Model for these predictors: 'day', 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               1.14984321364295   0.204694337023034  [1, 2, 7]
#     2               0.793676597551535  0.20209011081849   [1, 2, 7]
#     3               0.372567277891865  0.203182310219422  [1, 2, 7]
#     4               4.86078590699068   0.201530128393594  [1, 2, 7]
#     5               0.300036125931618  0.199054813130497  [1, 2, 7]
#
# Mean RMSE for "Linear Regression Model": 1.4953818244017298
# Median RMSE for "Linear Regression Model": 0.7936765975515352
# Mean RMSE for "Mean Model": 0.20211033991700744
# Median RMSE for "Mean Model": 0.20209011081848977
#
# Validate for these predictors: 'day', 'year', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.265856410737961  [1, 2, 7]
#     2       0.267214218322537  [1, 2, 7]
#     3       0.266767353227339  [1, 2, 7]
#     4       0.262120293074847  [1, 2, 7]
#     5       0.260248719516089  [1, 2, 7]
#
# Mean RMSE for Validaton Data: 0.26444139897575464
# Median RMSE for Validaton Data: 0.2658564107379614
#
# -------
#
# Model for these predictors: 'day', 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.26486994263733   0.202993742530274  [1, 3, 5]
#     2               0.306536278369819  0.200397016661145  [1, 3, 5]
#     3               0.256710077453285  0.202135220103739  [1, 3, 5]
#     4               0.306156681825544  0.201595486462022  [1, 3, 5]
#     5               0.597169927770458  0.198584937558572  [1, 3, 5]
#
# Mean RMSE for "Linear Regression Model": 0.34628858161128695
# Median RMSE for "Linear Regression Model": 0.3061566818255436
# Mean RMSE for "Mean Model": 0.2011412806631502
# Median RMSE for "Mean Model": 0.2015954864620216
#
# Validate for these predictors: 'day', 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.558395605566311  [1, 3, 5]
#     2       0.570996043030349  [1, 3, 5]
#     3       0.558158530072193  [1, 3, 5]
# ...
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# |  99 |  1.74620582994267  |     0.204817765267054 | day_index    |       5 |   0.275033917869339 |            5 |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 100 |  1.802435040975    |     0.203681390917672 | day          |       5 |   0.167577664561483 |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 101 |  1.82998107874608  |     0.203289451725158 | day          |       5 |   1.35106181443129  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 102 |  1.90757979185722  |     0.20452845223725  | year         |       5 |   0.570230418941675 |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 103 |  1.93845695987856  |     0.203798569029374 | day          |       5 |   1.93718216932019  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 104 |  2.11054586623269  |     0.204166731505305 | year         |       5 |   4.39462773463477  |            5 |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 105 |  2.18200685503755  |     0.201911155556922 | year         |       5 |   1.77045086880728  |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 106 |  2.29540235304513  |     0.200270625983133 | day_index    |       5 |   4.12245036983074  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 107 |  2.45308821974695  |     0.204411820213686 | day_index    |       5 |   3.30399526955818  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 108 |  2.55798615290499  |     0.204173277604792 | year         |       5 |   0.504485193247481 |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 109 |  2.71214136763079  |     0.203065589518062 | year         |       5 |  12.6216446215048   |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 110 |  2.84796548351083  |     0.204608905403399 | day          |       5 |  16.3584024727454   |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 111 |  2.86884307235934  |     0.205249893025536 | day          |       5 |  17.4466788388541   |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 112 |  2.98145916550049  |     0.203601423665318 | day_index    |       5 |   0.62755680653458  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 113 |  3.20312496834363  |     0.203293570066961 | day_index    |       5 |  16.1817873193345   |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 114 |  3.37315239388369  |     0.201259432568594 | year         |       5 |  14.1706437708813   |            5 |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 115 |  4.16904977270329  |     0.202447630675298 | year         |       5 |   8.46547903079523  |            5 |
# |     |                    |                       | temp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 116 |  4.25452862671442  |     0.202749720684539 | day_index    |       5 |   3.14585921914819  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 117 |  4.61418652157213  |     0.20559086846388  | day_index    |       5 |   3.20784187445449  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 118 |  4.81419239098053  |     0.201347330237466 | year         |       5 |   5.37702085763739  |            5 |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 119 |  4.85713858307815  |     0.203541262300855 | year         |       5 |   0.29851027421675  |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 120 |  4.88852507617008  |     0.203376121536984 | day          |       5 |   1.5071137833246   |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 121 |  5.26815702241249  |     0.203247090337308 | year         |       5 |   5.25109348831662  |            5 |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 122 |  5.38981862700985  |     0.203255635864996 | year         |       5 |   0.272766005027986 |            5 |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 123 |  5.80797839244858  |     0.203474654148617 | day_index    |       5 |  13.5807172223108   |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 124 |  6.80087640525713  |     0.204012678966232 | day          |       5 |   6.76920455513628  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 125 |  9.94143633808659  |     0.201739121430451 | day_index    |       5 |  10.2792806213124   |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 126 | 11.1271790412954   |     0.204000884705069 | day_index    |       5 |   0.871766000160139 |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+

# %%
# print all results in memory from all runs (optional)
print(all_rmse_results)
# Out:
# [{'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 0.4054182509972351, 'Mean Model RMSE': 0.2060373701028115, 'Predictors Columns': [0]}, {'Run': 2, 'Linear Regression Model RMSE': 2.6402158307861865, 'Mean Model RMSE': 0.2041557354071232, 'Predictors Columns': [0]}, {'Run': 3, 'Linear Regression Model RMSE': 0.2995878361175569, 'Mean Model RMSE': 0.20449631168870477, 'Predictors Columns': [0]}, {'Run': 4, 'Linear Regression Model RMSE': 3.301639294390229, 'Mean Model RMSE': 0.204396191667258, 'Predictors Columns': [0]}, {'Run': 5, 'Linear Regression Model RMSE': 0.3467646665018612, 'Mean Model RMSE': 0.20475245320280677, 'Predictors Columns': [0]}], 'validation_results': [{'Run': 1, 'Validation Test RMSE': 0.3048384581475494, 'Predictors Columns': [0]}, {'Run': 2, 'Validation Test RMSE': 0.27754416731995557, 'Predictors Columns': [0]}, {'Run': 3, 'Validation Test RMSE': 0.2939293034760735, 'Predictors Columns': [0]}, {'Run': 4, 'Validation Test RMSE': 0.24527119177316156, 'Predictors Columns': [0]}, {'Run': 5, 'Validation Test RMSE': 0.25691680527812527, 'Predictors Columns': [0]}]}, {'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 0.20407730262517831, 'Mean Model RMSE': 0.2030699526108162, 'Predictors Columns': [1]}, {'Run': 2, 'Linear Regression Model RMSE': 0.20470355436361143, 'Mean Model RMSE': 0.1995225680144767, 'Predictors Columns': [1]}, {'Run': 3, 'Linear Regression Model RMSE': 0.20813193976770653, 'Mean Model RMSE': 0.20481112101399568, 'Predictors Columns': [1]}, {'Run': 4, 'Linear Regression Model RMSE': 0.20209766487577777, 'Mean Model RMSE': 0.2010029805161207, 'Predictors Columns': [1]}, {'Run': 5, 'Linear Regression Model RMSE': 0.2076585337296739, 'Mean Model RMSE': 0.20110303092576337, 'Predictors Columns': [1]}], 'validation_results': [{'Run': 1, 'Validation Test RMSE': 0.14317655675288146, 'Predictors Columns': [1]}, {'Run': 2, 'Validation Test RMSE': 0.1680735007223773, 'Predictors Columns': [1]}, {'Run': 3, 'Validation Test RMSE': 0.13463199822957106, 'Predictors Columns': [1]}, {'Run': 4, 'Validation Test RMSE': 0.15233720888357047, 'Predictors Columns': [1]}, {'Run': 5, 'Validation Test RMSE': 0.1661725576878072, 'Predictors Columns': [1]}]}, {'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 7.279829077244907, 'Mean Model RMSE': 0.2020758690766512, 'Predictors Columns': [2]}, {'Run': 2, 'Linear Regression Model RMSE': 0.6058513005503047, 'Mean Model RMSE': 0.20452205292421669, 'Predictors Columns': [2]}, {'Run': 3, 'Linear Regression Model RMSE': 15.814484634253315, 'Mean Model RMSE': 0.20181410651138768, 'Predictors Columns': [2]}, {'Run': 4, 'Linear Regression Model RMSE': 5.389818627009852, 'Mean Model RMSE': 0.20342014742881295, 'Predictors Columns': [2]}, {'Run': 5, 'Linear Regression Model RMSE': 0.31174471690638944, 'Mean Model RMSE': 0.20325563586499637, 'Predictors Columns': [2]}], 'validation_results': [{'Run': 1, 'Validation Test RMSE': 0.27283133799877124, 'Predictors Columns': [2]}, {'Run': 2, 'Validation Test RMSE': 0.2725576704389671, 'Predictors Columns': [2]}, {'Run': 3, 'Validation Test RMSE': 0.27280477960023264, 'Predictors Columns': [2]}, {'Run': 4, 'Validation Test RMSE': 0.2727660050279863, 'Predictors Columns': [2]}, {'Run': 5, 'Validation Test RMSE': 0.2724716245079715, 'Predictors Columns': [2]}]}, {'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 0.2068795493790472, 'Mean Model RMSE': 0.2032849540596187, 'Predictors Columns': [3]}, {'Run': 2, 'Linear Regression Model RMSE': 0.20402695030823984, 'Mean Model RMSE': 0.1993934442759815, 'Predictors Columns': [3]}, {'Run': 3, 'Linear Regression Model RMSE': 0.21013939548837104, 'Mean Model RMSE': 0.20104673189667926, 'Predictors Columns': [3]}, {'Run': 4, 'Linear Regression Model RMSE': 0.20266025886874556, 'Mean Model RMSE': 0.20016174140144732, 'Predictors Columns': [3]}, {'Run': 5, 'Linear Regression Model RMSE': 0.22450537189809808, 'Mean Model RMSE': 0.20379173613079687, 'Pre ...
