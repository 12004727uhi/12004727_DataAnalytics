# %% [markdown]
# <a href="https://colab.research.google.com/github/12004727uhi/12004727_DataAnalytics/blob/master/colab/12004727_assignment_2_linear_regression_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas, to create data frame
import pandas as pd
# import numpy for maths operations
import numpy as np
# import tensorflow for modelling
# %tensorflow_version 1.x
import tensorflow as tf
# import file management utilities
import shutil
# import package to create data tables
from tabulate import tabulate
# import iterable tools
import itertools
# Out:
# TensorFlow 1.x selected.

# %%
## Configuration
#
# enable logging for tensorflow (set to ERROR when automating, or INFO for diagnostic)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# define dataset friendly name (descriptive)
DATASET_TITLE = '2013 to 2019 - Bronx County [linear_6.csv]'
# define dataset csv name
DATASET_NAME = 'linear_6'
# define dataset CSV URL
DATA_URL = 'https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/linear_6.csv'
# define validation dataset CSV URL
VALIDATION_DATA_URL = 'https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/sample_linear_6.csv'
# import dataset CSV & assign to variable (type pandas df)
TRAIN_AND_TEST_DATA = pd.read_csv(DATA_URL, index_col=0,)
# import validation dataset CSV & assign to variable (type pandas df)
VALIDATION_DATA = pd.read_csv(VALIDATION_DATA_URL, index_col=0,)
# define number of targets
NUM_TARGETS = 1
# define predictors for training/testing
predictor_column_list = [0,1,2,3,5,6,7]
predictors = []
for idx, predictor in enumerate(predictor_column_list, 1):
  predictors.append([list(p) for p in itertools.combinations(predictor_column_list, idx)])
  pred = [list(p) for p in itertools.combinations(predictor_column_list, idx)]
PREDICTORS_COLS = list(itertools.chain(*predictors))
# define target column indexes
TARGETS_COLS = [8]
# define validation target column name(s)
VALIDATION_TARGETS = ['NUM_COLLISIONS']
# URI of model
MODEL_URI = f'/tmp/trained_model_{DATASET_NAME}'
# define how many model runs for training & testing
NUMBER_OF_MODEL_RUNS = 5
# Define scale parameter for number of collisions
SCALE_NUM_COLLISIONS = 1.0
# define number of estimator fit steps
ESTIMATOR_STEPS = 10000
# set training set size (percentage as decimal)
TRAINING_SET_SLICE = 0.8

# show first 5 rows to verify import
display(TRAIN_AND_TEST_DATA[:5])
# show first 5 rows to verify import
display(VALIDATION_DATA[:5])
# print length of predictors column list to verify
print(f'Predictors columns: {len(PREDICTORS_COLS)}')
# check the tensorflow version
print(f'Tensor flow version: {tf.__version__}')
# Out:
#      day_index  day  year  mo        county  temp  visib  wdsp  NUM_COLLISIONS
# 375          5    2  2013   1  Bronx County  38.0   10.0  15.0        0.127193
# 382          7    3  2013   1  Bronx County  27.5   10.0  12.4        0.232456
# 395         15    4  2013   1  Bronx County  21.8   10.0   9.8        0.258772
# 401         16    5  2013   1  Bronx County  32.2   10.0  11.3        0.241228
# 411         21    6  2013   1  Bronx County  37.3   10.0  13.2        0.171053
#        day_index  day  year  mo  ...  temp  visib  wdsp  NUM_COLLISIONS
# 4602        2388    2  2019   4  ...  48.8    6.3  11.4        0.648069
# 1238         493    7  2014   1  ...  26.8    9.4  17.8        0.470874
# 176         1597    6  2017   1  ...  38.7   10.0  18.3        0.585153
# 15242       1193    2  2016  11  ...  47.2   10.0   7.1        0.691983
# 1739         939    3  2015   2  ...  32.6    9.9  23.9        0.647321
#
# [5 rows x 9 columns]
# Predictors columns: 127
# Tensor flow version: 1.15.2

# %%
# define function to create table of training/testing results & compute RSME
def create_results_table(rmse_results):
  # calculate mean & median RMSEs
  regression_RMSE_list = [n['Linear Regression Model RMSE'] for n in rmse_results]
  mean_model_RMSE_list = [n['Mean Model RMSE'] for n in rmse_results]
  regression_mean_RMSE = np.mean(regression_RMSE_list)
  mean_mean_RMSE = np.mean(mean_model_RMSE_list)
  regression_median_RMSE = np.median(regression_RMSE_list)
  mean_median_RMSE = np.median(mean_model_RMSE_list)
  header = rmse_results[0].keys()
  rows =  [x.values() for x in rmse_results]
  # ONLY PRINT OUTPUT IF regression_median_RMSE <= 1.0
  if regression_median_RMSE < 1.0:
    print(tabulate(rows, header, floatfmt=".15"))
    # print mean & median RMSEs
    print(f'\nMean RMSE for "Linear Regression Model": {regression_mean_RMSE}')
    print(f'Median RMSE for "Linear Regression Model": {regression_median_RMSE}')
    print(f'Mean RMSE for "Mean Model": {mean_mean_RMSE}')
    print(f'Median RMSE for "Mean Model": {mean_median_RMSE}\n')
    return True
  else:
    print(f'Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.')
    return False

# %%
# function to create table of validation results & compute RSME
def create_validation_table(validation_results):
  header = validation_results[0].keys()
  rows =  [x.values() for x in validation_results]
  # print table
  print(tabulate(rows, header, floatfmt=".15"))
  # calculate mean & median RMSEs
  validation_RMSE_list = [n['Validation Test RMSE'] for n in validation_results]
  validation_mean_RMSE = np.mean(validation_RMSE_list)
  validation_median_RMSE = np.median(validation_RMSE_list)
  # print mean & median RMSEs
  print(f'\nMean RMSE for Validaton Data: {validation_mean_RMSE}')
  print(f'Median RMSE for Validaton Data: {validation_median_RMSE}')

# %%
# function to generate rank table of median rmse result over n runs
def create_rank_table(all_results):
  # define final table lists
  table_list = []
  # compile table list with medians 
  for model in all_results:
    run_rmse_list = [run['Linear Regression Model RMSE'] for run in model['model_results']]
    run_mean_model_rmse_list = [run['Mean Model RMSE'] for run in model['model_results']]
    run_validation_rmse_list = [run['Validation Test RMSE'] for run in model['validation_results']]
    table_list.append({'Median RMSE\n(Ranked)': np.median(run_rmse_list), 
                       'Median \'Mean Model\'\nRMSE': np.median(run_mean_model_rmse_list),
                       'Model\nPredictors': '\n'.join([TRAIN_AND_TEST_DATA.columns[c] for c in model['model_results'][0]['Predictors Columns']]),
                       'Model\nRuns': len(run_rmse_list),
                       'Median Validation\nRMSE': np.median(run_validation_rmse_list),
                       'Validation\nRuns': len(run_validation_rmse_list)
                       })
  # rank medians
  sorted_table_list = sorted(table_list, key=lambda d: d['Median RMSE\n(Ranked)'])
  # display table
  print('\n----------------------------------------------------------------')
  print('Ranked Table of Median RMSE Results for Linear Regression Models')
  print('----------------------------------------------------------------')
  print('Tensor Flow Linear Regression Output')
  print(f'Model dataset title: {DATASET_TITLE}')
  print(f'Model dataset CSV: {DATA_URL}')
  print(f'Model validation dataset CSV: {VALIDATION_DATA_URL}\n')
  header = sorted_table_list[0].keys()
  rows =  [x.values() for x in sorted_table_list]
  print(tabulate(rows, header, floatfmt=".15", showindex='always', tablefmt="grid"))

# %%
## define function to validate against normalised, processed dataset
# set pandas to display _all_ columns
pd.set_option('display.max_columns', None)
def run_validation(validation_predictors_cols):
  # shuffle data
  shuffled_validation_data = VALIDATION_DATA.iloc[np.random.permutation(len(VALIDATION_DATA))]
  # assign predictors to variables
  predictors_validation_data = shuffled_validation_data.iloc[:,validation_predictors_cols]
  # define TensorFlow estimator
  estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.LinearRegressor(model_dir=MODEL_URI, enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors_validation_data.values)))
  # check predictions based on defined predictors and assign result to variable
  validation_predictions = estimator.predict(x=predictors_validation_data.values)
  # extract a list of the resulting prediction scores
  validation_prediction_scores = validation_predictions['scores']
  # define validation data targets
  targets_validation = pd.DataFrame(list(VALIDATION_DATA[t] for t in VALIDATION_TARGETS))
  # calculate RMSE for regression model and actual validation collision data
  validation_rmse = np.sqrt(np.mean((targets_validation.values - validation_prediction_scores)**2))
  # return  results
  return validation_rmse

# %%
# function to generate table of validation results
def gen_validation_results_table(validation_result_list):
  create_validation_table(validation_result_list)

# function to generate table of results
def gen_results_table(rmse_result_list):
  return create_results_table(rmse_result_list)

# function to do validation
def do_validation(predictors_combination):
  return run_validation(predictors_combination)
  
# function to loop linear regressor n times (shuffling data each time). Returns dict of RMSE results.
def run_linear_regressor(predictors_cols):
  # define result lists to return
  result_list = []
  validation_result_list = []
  for idx, run in enumerate(range(NUMBER_OF_MODEL_RUNS)):
    # shuffle data & print first 5 rows
    shuffled = TRAIN_AND_TEST_DATA.iloc[np.random.permutation(len(TRAIN_AND_TEST_DATA))]
    # assign predictors to variable
    predictors = shuffled.iloc[:,predictors_cols]
    # assign targets to variable
    targets = shuffled.iloc[:,TARGETS_COLS]
    # define training set size - 80% of the shuffled data array length
    training_set_size = int(len(shuffled['NUM_COLLISIONS'])*TRAINING_SET_SLICE)
    # define test set size - the remaining of the shuffled data array length
    test_set_size = len(shuffled['NUM_COLLISIONS']) - training_set_size
    # Define number of targets (outputs)
    num_of_targets = NUM_TARGETS
    # ensure any previously saved training run models are removed
    shutil.rmtree(MODEL_URI, ignore_errors=True)
    # define the TensorFlow estimator
    estimator = tf.contrib.learn.SKCompat(
        tf.contrib.learn.LinearRegressor(
            model_dir=MODEL_URI, 
            optimizer=tf.train.AdamOptimizer(learning_rate=0.1), 
            enable_centered_bias=False, 
            feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors.values) 
            )
        )
    # train the model, using previously defined predictor & target values
    estimator.fit(predictors[:training_set_size].values, 
                  targets[:training_set_size].values.reshape(
                      training_set_size, num_of_targets)/SCALE_NUM_COLLISIONS, steps=ESTIMATOR_STEPS
                  )
    # check predictions based on defined predictors and assign result to variable
    predictions = estimator.predict(x=predictors[training_set_size:].values)
    # Apply scaling to output (not require here as previously discussed)
    predictions_scaled = predictions['scores']*SCALE_NUM_COLLISIONS
    # format predictions as strings to make readable in printing to check output etc
    predictions_formatted = format(str(predictions_scaled))
    # calculate RSME to determine how well the model is predicting the targets from the predictors
    rmse_linear_model = np.sqrt(np.mean((targets[training_set_size:].values - predictions_scaled)**2))
    # calculate mean of the normalised collision values
    mean_norm_collisions = np.mean(shuffled['NUM_COLLISIONS'][:training_set_size])
    # calculate the RMSE of line of best fit that simply follows a mean of target values.
    # This allows comparison between the 'mean model' and the proposed linear regression model.
    # If the linear regression model is successful, it will show a 'better fit' than the 'mean model'
    # i.e., the resulting calculation should be *lower*.
    rmse_mean_model = np.sqrt(np.mean((shuffled['NUM_COLLISIONS'][training_set_size:] - mean_norm_collisions)**2))
    # add rmse calculations to result list
    result_list.append({'Run': idx+1, 'Linear Regression Model RMSE': rmse_linear_model, 'Mean Model RMSE': rmse_mean_model, 'Predictors Columns': predictors_cols})
    # perform validation process
    validation_result_list.append({'Run': idx+1, 'Validation Test RMSE' : do_validation(predictors_cols), 'Predictors Columns': predictors_cols})
  # draw table
  model_table_generated = gen_results_table(result_list)
  # draw validation table results table only if model table was also drawn
  if model_table_generated:
    print('Validate for these predictors: {}'.format(", ".join(f"\'{VALIDATION_DATA.columns[c]}\'" for c in predictors_cols)))
    print('Validate for these targets: {}\n'.format(", ".join(f"\'{t}\'" for t in VALIDATION_TARGETS)))
    gen_validation_results_table(validation_result_list)
  # return results
  return [result_list, validation_result_list]

# %%
# - run all models n times, for all predictor combinations on imported datasets;
# - calculate & tabulate RMSEs for each model run & then calculate mean RMSE;
# - run model n time on validation datasets, for all predictor combinations;
# - calculate RMSE for each model validation run & then calculate mean RMSE;

# function to do modelling & validation
def model_and_validate():
  # define list to retain all results in memory for further analysis if necessary
  all_rmse_results = []
  # print sheet header
  print(f'Tensor Flow Linear Regression Output')
  print(f'Model dataset title: {DATASET_TITLE}')
  print(f'Model dataset CSV: {DATA_URL}')
  print(f'Model validation dataset CSV: {VALIDATION_DATA_URL}')
  print(f'------------------------------------------------------------------------------\n')
  for predictors_combination in PREDICTORS_COLS:
    # print the predictor combination
    print('Model for these predictors: {}'.format(", ".join(f"\'{TRAIN_AND_TEST_DATA.columns[c]}\'" for c in predictors_combination)))
    print('Model for these targets: {}\n'.format(", ".join(f"\'{TRAIN_AND_TEST_DATA.columns[t]}\'" for t in TARGETS_COLS)))
    results = run_linear_regressor(predictors_combination)
    # add results to in-memory list
    all_rmse_results.append({'model_results': results[0], 'validation_results': results[1]})
    print(f'\n-------\n')
  # generate rank table of median rmse result over n runs
  generate_rank_table(all_rmse_results)
  return all_rmse_results

# function to generate rank table of results
def generate_rank_table(all_results):
  create_rank_table(all_results)
  
all_rmse_results = model_and_validate()
# Out:
# Tensor Flow Linear Regression Output
# Model dataset title: 2013 to 2019 - Bronx County [linear_6.csv]
# Model dataset CSV: https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/linear_6.csv
# Model validation dataset CSV: https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/sample_linear_6.csv
# ------------------------------------------------------------------------------
#
# Model for these predictors: 'day_index'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.243712328808183  0.204670630630956  [0]
#     2               3.82847876015745   0.2014264885699    [0]
#     3               0.273281330973495  0.203351547268638  [0]
#     4               1.2520204265925    0.200599657374813  [0]
#     5               0.335419738736407  0.202399098080272  [0]
#
# Mean RMSE for "Linear Regression Model": 1.1865825170536055
# Median RMSE for "Linear Regression Model": 0.3354197387364066
# Mean RMSE for "Mean Model": 0.2024894843849156
# Median RMSE for "Mean Model": 0.20239909808027182
#
# Validate for these predictors: 'day_index'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.107464078295858  [0]
#     2       3.19840339393597   [0]
#     3       0.229924233823456  [0]
#     4       1.03975129451582   [0]
#     5       0.273498952922731  [0]
#
# Mean RMSE for Validaton Data: 0.9698083906987653
# Median RMSE for Validaton Data: 0.27349895292273074
#
# -------
#
# Model for these predictors: 'day'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.221364897982545  0.203802104800481  [1]
#     2               0.24853998907718   0.208100190490022  [1]
#     3               0.201914607695764  0.19990866826973   [1]
#     4               0.208305065018898  0.201346034948562  [1]
#     5               0.206107564815336  0.203984796498948  [1]
#
# Mean RMSE for "Linear Regression Model": 0.2172464249179445
# Median RMSE for "Linear Regression Model": 0.20830506501889787
# Mean RMSE for "Mean Model": 0.20342835900154857
# Median RMSE for "Mean Model": 0.2038021048004812
#
# Validate for these predictors: 'day'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.172604338380328  [1]
#     2       0.191924486398619  [1]
#     3       0.156967287376651  [1]
#     4       0.153780770114402  [1]
#     5       0.150575579741921  [1]
#
# Mean RMSE for Validaton Data: 0.16517049240238413
# Median RMSE for Validaton Data: 0.15696728737665094
#
# -------
#
# Model for these predictors: 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.207886166871839  0.206698238421133  [3]
#     2               0.211182786401897  0.204938772275191  [3]
#     3               0.208330361143361  0.20187602101257   [3]
#     4               0.221504679030269  0.208002644287323  [3]
#     5               0.20751202025151   0.205656509956793  [3]
#
# Mean RMSE for "Linear Regression Model": 0.21128320273977538
# Median RMSE for "Linear Regression Model": 0.20833036114336076
# Mean RMSE for "Mean Model": 0.20543443719060214
# Median RMSE for "Mean Model": 0.20565650995679258
#
# Validate for these predictors: 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.146974092809179  [3]
#     2       0.141497849727961  [3]
#     3       0.160592909326464  [3]
#     4       0.162342940151683  [3]
#     5       0.151796781730892  [3]
#
# Mean RMSE for Validaton Data: 0.1526409147492356
# Median RMSE for Validaton Data: 0.1517967817308916
#
# -------
#
# Model for these predictors: 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.234029387129113  0.200074976911976  [5]
#     2               0.287426577115778  0.203411716961804  [5]
#     3               0.278303792618201  0.207800735153815  [5]
#     4               0.477890310420151  0.200904253301719  [5]
#     5               0.317529848377315  0.207688581077054  [5]
#
# Mean RMSE for "Linear Regression Model": 0.3190359831321114
# Median RMSE for "Linear Regression Model": 0.28742657711577835
# Mean RMSE for "Mean Model": 0.20397605268127372
# Median RMSE for "Mean Model": 0.20341171696180357
#
# Validate for these predictors: 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.187524768001594  [5]
#     2       0.251442355711251  [5]
#     3       0.212617765199891  [5]
#     4       0.405080919070396  [5]
#     5       0.244584933416846  [5]
#
# Mean RMSE for Validaton Data: 0.26025014827999565
# Median RMSE for Validaton Data: 0.2445849334168463
#
# -------
#
# Model for these predictors: 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.204404244438967  0.204220556959005  [6]
#     2               0.24670003079396   0.205923131302264  [6]
#     3               0.232190736489749  0.204350199949593  [6]
#     4               0.229261134947786  0.199276747706717  [6]
#     5               0.203568648526651  0.203481906505795  [6]
#
# Mean RMSE for "Linear Regression Model": 0.22322495903942277
# Median RMSE for "Linear Regression Model": 0.22926113494778638
# Mean RMSE for "Mean Model": 0.20345050848467464
# Median RMSE for "Mean Model": 0.20422055695900498
#
# Validate for these predictors: 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.140327962774823  [6]
#     2       0.190442543855057  [6]
#     3       0.192023366074033  [6]
#     4       0.17573977398369   [6]
#     5       0.142723180695071  [6]
#
# Mean RMSE for Validaton Data: 0.16825136547653458
# Median RMSE for Validaton Data: 0.17573977398369017
#
# -------
#
# Model for these predictors: 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.204099190565728  0.203494377638085  [7]
#     2               0.208843565500178  0.205143119702886  [7]
#     3               0.233950739893326  0.205258487955712  [7]
#     4               0.213571501025361  0.205480993747304  [7]
#     5               0.207543507704156  0.202271052547757  [7]
#
# Mean RMSE for "Linear Regression Model": 0.21360170093774983
# Median RMSE for "Linear Regression Model": 0.2088435655001778
# Mean RMSE for "Mean Model": 0.2043296063183488
# Median RMSE for "Mean Model": 0.20514311970288637
#
# Validate for these predictors: 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.141044762119201  [7]
#     2       0.142686721375486  [7]
#     3       0.192768325401902  [7]
#     4       0.156083600757767  [7]
#     5       0.15173942998149   [7]
#
# Mean RMSE for Validaton Data: 0.15686456792716924
# Median RMSE for Validaton Data: 0.15173942998149045
#
# -------
#
# Model for these predictors: 'day_index', 'day'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.606551812802993  0.199679038726893  [0, 1]
#     2               0.67626410121606   0.202324076009109  [0, 1]
#     3               0.321471548344308  0.204972122838636  [0, 1]
#     4               0.22767327434329   0.199792852120733  [0, 1]
#     5               0.230422802097286  0.201209647737493  [0, 1]
#
# Mean RMSE for "Linear Regression Model": 0.4124767077607873
# Median RMSE for "Linear Regression Model": 0.32147154834430847
# Mean RMSE for "Mean Model": 0.20159554748657288
# Median RMSE for "Mean Model": 0.20120964773749306
#
# Validate for these predictors: 'day_index', 'day'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.506246592908393  [0, 1]
#     2       0.546520370920935  [0, 1]
#     3       0.25009667903129   [0, 1]
#     4       0.160668761059544  [0, 1]
#     5       0.180429928634253  [0, 1]
#
# Mean RMSE for Validaton Data: 0.328792466510883
# Median RMSE for Validaton Data: 0.25009667903129007
#
# -------
#
# Model for these predictors: 'day_index', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               1.02770970656967   0.205631177712683  [0, 3]
#     2              20.1872778041729    0.200423181133643  [0, 3]
#     3               0.279380749695858  0.199093650946196  [0, 3]
#     4               0.450931218187799  0.203880239650367  [0, 3]
#     5               0.218940879009609  0.206687701518712  [0, 3]
#
# Mean RMSE for "Linear Regression Model": 4.432848071527161
# Median RMSE for "Linear Regression Model": 0.4509312181877991
# Mean RMSE for "Mean Model": 0.2031431901923204
# Median RMSE for "Mean Model": 0.20388023965036722
#
# Validate for these predictors: 'day_index', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.871945703828853  [0, 3]
#     2      16.9492249305636    [0, 3]
#     3       0.212252677251167  [0, 3]
#     4       0.384344449665752  [0, 3]
#     5       0.166014820665915  [0, 3]
#
# Mean RMSE for Validaton Data: 3.716756516395062
# Median RMSE for Validaton Data: 0.38434444966575204
#
# -------
#
# Model for these predictors: 'day_index', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.486062301892943  0.202767029975391  [0, 5]
#     2               0.405128731458025  0.204920131213441  [0, 5]
#     3               0.425567686482112  0.202400239437576  [0, 5]
#     4               0.253234932376953  0.203915602693922  [0, 5]
#     5               0.209390987531663  0.20289892863016   [0, 5]
#
# Mean RMSE for "Linear Regression Model": 0.3558769279483391
# Median RMSE for "Linear Regression Model": 0.40512873145802464
# Mean RMSE for "Mean Model": 0.20338038639009812
# Median RMSE for "Mean Model": 0.20289892863016018
#
# Validate for these predictors: 'day_index', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.418324686442571  [0, 5]
#     2       0.294345666822093  [0, 5]
#     3       0.350429612565477  [0, 5]
#     4       0.209044646548852  [0, 5]
#     5       0.166607175165997  [0, 5]
#
# Mean RMSE for Validaton Data: 0.287750357508998
# Median RMSE for Validaton Data: 0.2943456668220933
#
# -------
#
# Model for these predictors: 'day_index', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.214002880289437  0.204060349594828  [0, 6]
#     2               0.209102050855635  0.205309019145305  [0, 6]
#     3               0.316083937038826  0.200427289475624  [0, 6]
#     4               0.246817900978347  0.207120604986064  [0, 6]
#     5               0.21814432571759   0.202223225529533  [0, 6]
#
# Mean RMSE for "Linear Regression Model": 0.24083021897596693
# Median RMSE for "Linear Regression Model": 0.21814432571759
# Mean RMSE for "Mean Model": 0.20382809774627111
# Median RMSE for "Mean Model": 0.2040603495948283
#
# Validate for these predictors: 'day_index', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.155020007920158  [0, 6]
#     2       0.156745474187166  [0, 6]
#     3       0.277838466628144  [0, 6]
#     4       0.142442616637863  [0, 6]
#     5       0.165058472646152  [0, 6]
#
# Mean RMSE for Validaton Data: 0.1794210076038965
# Median RMSE for Validaton Data: 0.1567454741871659
#
# -------
#
# Model for these predictors: 'day_index', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.215457495734112  0.205002439215836  [1, 3]
#     2               0.20784337096296   0.203412955379046  [1, 3]
#     3               0.21312339663737   0.20260885663664   [1, 3]
#     4               0.217398785387646  0.201453070263519  [1, 3]
#     5               0.216339041050496  0.204735486520723  [1, 3]
#
# Mean RMSE for "Linear Regression Model": 0.21403241795451663
# Median RMSE for "Linear Regression Model": 0.2154574957341116
# Mean RMSE for "Mean Model": 0.203442561603153
# Median RMSE for "Mean Model": 0.20341295537904625
#
# Validate for these predictors: 'day', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.154893124775801  [1, 3]
#     2       0.15051374101154   [1, 3]
#     3       0.138747189679771  [1, 3]
#     4       0.156038724451946  [1, 3]
#     5       0.150080012201109  [1, 3]
#
# Mean RMSE for Validaton Data: 0.1500545584240335
# Median RMSE for Validaton Data: 0.15051374101154003
#
# -------
#
# Model for these predictors: 'day', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.274558760087373  0.203315810163404  [1, 5]
#     2               0.227900693766105  0.202948746391906  [1, 5]
#     3               0.278640233263942  0.201678305187241  [1, 5]
#     4               0.240942198177931  0.203559636417726  [1, 5]
#     5               0.291648258982993  0.199555121774066  [1, 5]
#
# Mean RMSE for "Linear Regression Model": 0.26273802885566877
# Median RMSE for "Linear Regression Model": 0.2745587600873732
# Mean RMSE for "Mean Model": 0.20221152398686854
# Median RMSE for "Mean Model": 0.20294874639190622
#
# Validate for these predictors: 'day', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.218558538302533  [1, 5]
#     2       0.150041616985686  [1, 5]
#     3       0.25943512669779   [1, 5]
#     4       0.187607885146486  [1, 5]
#     5       0.248973174004342  [1, 5]
#
# Mean RMSE for Validaton Data: 0.21292326822736754
# Median RMSE for Validaton Data: 0.21855853830253325
#
# -------
#
# Model for these predictors: 'day', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.210540324323025  0.205283063917896  [1, 6]
#     2               0.206078881527215  0.203193667019673  [1, 6]
#     3               0.222724289241303  0.206858060521653  [1, 6]
#     4               0.204565020098751  0.201475414615116  [1, 6]
#     5               0.214041526973692  0.209134822746243  [1, 6]
#
# Mean RMSE for "Linear Regression Model": 0.21159000843279713
# Median RMSE for "Linear Regression Model": 0.2105403243230249
# Mean RMSE for "Mean Model": 0.20518900576411608
# Median RMSE for "Mean Model": 0.2052830639178959
#
# Validate for these predictors: 'day', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.143677246679826  [1, 6]
#     2       0.14585462737105   [1, 6]
#     3       0.155859119272316  [1, 6]
#     4       0.136002812722712  [1, 6]
#     5       0.131194052285285  [1, 6]
#
# Mean RMSE for Validaton Data: 0.14251757166623774
# Median RMSE for Validaton Data: 0.1436772466798262
#
# -------
#
# Model for these predictors: 'day', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.246889979237847  0.206349092601984  [1, 7]
#     2               0.211046548305093  0.199157996436197  [1, 7]
#     3               0.207850213552001  0.205365726682266  [1, 7]
#     4               0.20078217263412   0.197859143764229  [1, 7]
#     5               0.210662312267694  0.20875980237703   [1, 7]
#
# Mean RMSE for "Linear Regression Model": 0.2154462451993509
# Median RMSE for "Linear Regression Model": 0.21066231226769372
# Mean RMSE for "Mean Model": 0.2034983523723412
# Median RMSE for "Mean Model": 0.20536572668226608
#
# Validate for these predictors: 'day', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.136318679190275  [1, 7]
#     2       0.163231976431043  [1, 7]
#     3       0.154630766356496  [1, 7]
#     4       0.162205713206985  [1, 7]
#     5       0.151478136467747  [1, 7]
#
# Mean RMSE for Validaton Data: 0.15357305433050933
# Median RMSE for Validaton Data: 0.15463076635649572
#
# -------
#
# Model for these predictors: 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.205610709538726  0.202230833878843  [3, 5]
#     2               0.272080097000115  0.203145283968957  [3, 5]
#     3               0.252963421323673  0.205972120550094  [3, 5]
#     4               0.231811445042202  0.20523530376611   [3, 5]
#     5               0.364924625452598  0.201262707758049  [3, 5]
#
# Mean RMSE for "Linear Regression Model": 0.2654780596714628
# Median RMSE for "Linear Regression Model": 0.2529634213236729
# Mean RMSE for "Mean Model": 0.20356924998441056
# Median RMSE for "Mean Model": 0.2031452839689567
#
# Validate for these predictors: 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.145020178693415  [3, 5]
#     2       0.196327912704185  [3, 5]
#     3       0.177980152931852  [3, 5]
#     4       0.177678567475314  [3, 5]
#     5       0.314043300201393  [3, 5]
#
# Mean RMSE for Validaton Data: 0.20221002240123184
# Median RMSE for Validaton Data: 0.17798015293185193
#
# -------
#
# Model for these predictors: 'mo', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.206819776867524  0.205755520698786  [3, 6]
#     2               0.208364628938693  0.205386743176263  [3, 6]
#     3               0.213557463894085  0.199999360743216  [3, 6]
#     4               0.24010063047668   0.205278691213928  [3, 6]
#     5               0.260232795437047  0.201602857873367  [3, 6]
#
# Mean RMSE for "Linear Regression Model": 0.2258150591228057
# Median RMSE for "Linear Regression Model": 0.21355746389408517
# Mean RMSE for "Mean Model": 0.20360463474111187
# Median RMSE for "Mean Model": 0.20527869121392753
#
# Validate for these predictors: 'mo', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.144764039906192  [3, 6]
#     2       0.146655967950255  [3, 6]
#     3       0.164373745204724  [3, 6]
#     4       0.158604729176321  [3, 6]
#     5       0.209272013649994  [3, 6]
#
# Mean RMSE for Validaton Data: 0.16473409917749718
# Median RMSE for Validaton Data: 0.1586047291763211
#
# -------
#
# Model for these predictors: 'mo', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.214206508570756  0.20693435613343   [3, 7]
#     2               0.216631216641577  0.203816327661022  [3, 7]
#     3               0.282161877057459  0.203668286126044  [3, 7]
#     4               0.235516066026293  0.202239105939709  [3, 7]
#     5               0.222966402251528  0.203803066622912  [3, 7]
#
# Mean RMSE for "Linear Regression Model": 0.23429641410952243
# Median RMSE for "Linear Regression Model": 0.2229664022515275
# Mean RMSE for "Mean Model": 0.20409222849662334
# Median RMSE for "Mean Model": 0.20380306662291206
#
# Validate for these predictors: 'mo', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.186059981313388  [3, 7]
#     2       0.191111096611113  [3, 7]
#     3       0.248210582164364  [3, 7]
#     4       0.181476249522594  [3, 7]
#     5       0.174106665814386  [3, 7]
#
# Mean RMSE for Validaton Data: 0.19619291508516895
# Median RMSE for Validaton Data: 0.18605998131338797
#
# -------
#
# Model for these predictors: 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.235442912203591  0.20424292824969   [5, 6]
#     2               0.367570055676486  0.203349468054351  [5, 6]
#     3               0.208966230728312  0.207509695733864  [5, 6]
#     4               0.378819670601618  0.201884278736543  [5, 6]
#     5               0.423015431962472  0.204886403808817  [5, 6]
#
# Mean RMSE for "Linear Regression Model": 0.32276286023449585
# Median RMSE for "Linear Regression Model": 0.36757005567648604
# Mean RMSE for "Mean Model": 0.204374554916653
# Median RMSE for "Mean Model": 0.20424292824968976
#
# Validate for these predictors: 'temp', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.203219937079369  [5, 6]
#     2       0.327905956154909  [5, 6]
#     3       0.142201134775946  [5, 6]
#     4       0.328322246374498  [5, 6]
#     5       0.38312175749074   [5, 6]
#
# Mean RMSE for Validaton Data: 0.2769542063750925
# Median RMSE for Validaton Data: 0.32790595615490914
#
# -------
#
# Model for these predictors: 'temp', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.21264998485654   0.204287413916744  [5, 7]
#     2               0.42762735518166   0.203503675820843  [5, 7]
#     3               0.316952763838042  0.204477548622088  [5, 7]
#     4               0.220284667034876  0.19875316975654   [5, 7]
#     5               0.226422292414231  0.201300720302134  [5, 7]
#
# Mean RMSE for "Linear Regression Model": 0.28078741266506957
# Median RMSE for "Linear Regression Model": 0.2264222924142305
# Mean RMSE for "Mean Model": 0.2024645056836699
# Median RMSE for "Mean Model": 0.20350367582084264
#
# Validate for these predictors: 'temp', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.152388305274682  [5, 7]
#     2       0.413021019299923  [5, 7]
#     3       0.284921683872135  [5, 7]
#     4       0.183468038779601  [5, 7]
#     5       0.176286389121423  [5, 7]
#
# Mean RMSE for Validaton Data: 0.24201708726955298
# Median RMSE for Validaton Data: 0.18346803877960116
#
# -------
#
# Model for these predictors: 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.237455399640906  0.202432936109809  [6, 7]
#     2               0.285491509107578  0.206084451012857  [6, 7]
#     3               0.238683321906765  0.202086055438497  [6, 7]
#     4               0.209004973991475  0.205789596275373  [6, 7]
#     5               0.20480529028192   0.20065706190893   [6, 7]
#
# Mean RMSE for "Linear Regression Model": 0.2350880989857287
# Median RMSE for "Linear Regression Model": 0.23745539964090576
# Mean RMSE for "Mean Model": 0.20341002014909337
# Median RMSE for "Mean Model": 0.2024329361098086
#
# Validate for these predictors: 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.186513305638211  [6, 7]
#     2       0.220060338807226  [6, 7]
#     3       0.211463200910051  [6, 7]
#     4       0.150101259863234  [6, 7]
#     5       0.143404997480565  [6, 7]
#
# Mean RMSE for Validaton Data: 0.18230862053985747
# Median RMSE for Validaton Data: 0.1865133056382105
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.624974188325384  0.205180114616539  [0, 1, 5]
#     2               0.271531413721874  0.199404709418858  [0, 1, 5]
#     3               0.239612846782045  0.199195567365875  [0, 1, 5]
#     4               1.84000459578863   0.204010071476231  [0, 1, 5]
#     5               0.359393686227805  0.205158397781779  [0, 1, 5]
#
# Mean RMSE for "Linear Regression Model": 0.6671033461691481
# Median RMSE for "Linear Regression Model": 0.359393686227805
# Mean RMSE for "Mean Model": 0.2025897721318565
# Median RMSE for "Mean Model": 0.2040100714762314
#
# Validate for these predictors: 'day_index', 'day', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.550594802838676  [0, 1, 5]
#     2       0.212256862088868  [0, 1, 5]
#     3       0.195357461698892  [0, 1, 5]
#     4       1.531776761636     [0, 1, 5]
#     5       0.238474971059743  [0, 1, 5]
#
# Mean RMSE for Validaton Data: 0.5456921718644346
# Median RMSE for Validaton Data: 0.2384749710597426
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               1.43216880662082   0.203666720507924  [0, 1, 6]
#     2               0.252542085174349  0.203810401680843  [0, 1, 6]
#     3               0.236379227289758  0.202499650087662  [0, 1, 6]
#     4               0.212411083856361  0.202969557846012  [0, 1, 6]
#     5               0.435321349886726  0.20388466836976   [0, 1, 6]
#
# Mean RMSE for "Linear Regression Model": 0.5137645105656021
# Median RMSE for "Linear Regression Model": 0.25254208517434884
# Mean RMSE for "Mean Model": 0.20336619969844025
# Median RMSE for "Mean Model": 0.20366672050792434
#
# Validate for these predictors: 'day_index', 'day', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       1.2203504164324    [0, 1, 6]
#     2       0.179171288582788  [0, 1, 6]
#     3       0.178359528535375  [0, 1, 6]
#     4       0.171003312169865  [0, 1, 6]
#     5       0.360143704626472  [0, 1, 6]
#
# Mean RMSE for Validaton Data: 0.4218056500693811
# Median RMSE for Validaton Data: 0.17917128858278838
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.275490384887831  0.203903006991923  [0, 1, 7]
#     2               0.248582086460199  0.207290280556155  [0, 1, 7]
#     3               1.20421370804677   0.202325969844839  [0, 1, 7]
#     4               0.462009778665554  0.20362796218522   [0, 1, 7]
#     5               0.233431410672871  0.201214043464861  [0, 1, 7]
#
# Mean RMSE for "Linear Regression Model": 0.484745473746646
# Median RMSE for "Linear Regression Model": 0.2754903848878314
# Mean RMSE for "Mean Model": 0.2036722526085996
# Median RMSE for "Mean Model": 0.20362796218521975
#
# Validate for these predictors: 'day_index', 'day', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.228812860267051  [0, 1, 7]
#     2       0.168341779661335  [0, 1, 7]
#     3       1.08609452560067   [0, 1, 7]
#     4       0.394027159033959  [0, 1, 7]
#     5       0.174293848015132  [0, 1, 7]
#
# Mean RMSE for Validaton Data: 0.4103140345156288
# Median RMSE for Validaton Data: 0.22881286026705083
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.516752522292305  0.204694954574815  [0, 2, 3]
#     2               0.220963590159539  0.198423177415873  [0, 2, 3]
#     3               0.696051233563019  0.203056453730828  [0, 2, 3]
#     4              10.5674812669568    0.200774728334935  [0, 2, 3]
#     5              18.8269712340973    0.203578342969585  [0, 2, 3]
#
# Mean RMSE for "Linear Regression Model": 6.16564396941378
# Median RMSE for "Linear Regression Model": 0.696051233563019
# Mean RMSE for "Mean Model": 0.2021055314052072
# Median RMSE for "Mean Model": 0.20305645373082848
#
# Validate for these predictors: 'day_index', 'year', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.515625168697729  [0, 2, 3]
#     2       0.176650010017505  [0, 2, 3]
#     3       0.655981330845536  [0, 2, 3]
#     4       9.9949911869583    [0, 2, 3]
#     5      17.4906165504856    [0, 2, 3]
#
# Mean RMSE for Validaton Data: 5.766772849400927
# Median RMSE for Validaton Data: 0.6559813308455363
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.231148733240336  0.203640341867413  [0, 2, 7]
#     2               0.458047772245823  0.203841304860852  [0, 2, 7]
#     3               0.958808061492458  0.20346818145335   [0, 2, 7]
#     4               0.237883813001544  0.203096981114807  [0, 2, 7]
#     5               1.64718047376811   0.203474062005104  [0, 2, 7]
#
# Mean RMSE for "Linear Regression Model": 0.7066137707496551
# Median RMSE for "Linear Regression Model": 0.4580477722458234
# Mean RMSE for "Mean Model": 0.2035041742603052
# Median RMSE for "Mean Model": 0.20347406200510368
#
# Validate for these predictors: 'day_index', 'year', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.140313626488637  [0, 2, 7]
#     2       0.443204808823312  [0, 2, 7]
#     3       0.902782503756428  [0, 2, 7]
#     4       0.181805202030047  [0, 2, 7]
#     5       1.56412795447439   [0, 2, 7]
#
# Mean RMSE for Validaton Data: 0.6464468191145624
# Median RMSE for Validaton Data: 0.44320480882331176
#
# -------
#
# Model for these predictors: 'day_index', 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.257974538747595  0.203519682537227  [0, 3, 5]
#     2               0.65526036104488   0.199489190369359  [0, 3, 5]
#     3               1.02069474423022   0.206635383216079  [0, 3, 5]
#     4               0.37715777937316   0.203588543568251  [0, 3, 5]
#     5               0.335038580158584  0.204065420813659  [0, 3, 5]
#
# Mean RMSE for "Linear Regression Model": 0.5292252007108873
# Median RMSE for "Linear Regression Model": 0.3771577793731602
# Mean RMSE for "Mean Model": 0.20345964410091497
# Median RMSE for "Mean Model": 0.20358854356825085
#
# Validate for these predictors: 'day_index', 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.154898740217373  [0, 3, 5]
#     2       0.554397798555424  [0, 3, 5]
#     3       0.916796422651182  [0, 3, 5]
#     4       0.274239404755249  [0, 3, 5]
#     5       0.217179361354316  [0, 3, 5]
#
# Mean RMSE for Validaton Data: 0.42350234550670873
# Median RMSE for Validaton Data: 0.27423940475524883
#
# -------
#
# Model for these predictors: 'day_index', 'mo', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.50815005923588   0.198981904603408  [0, 3, 6]
#     2               0.230949640060541  0.202318803532519  [0, 3, 6]
#     3               0.749882876101291  0.20210856675795   [0, 3, 6]
#     4              11.0235415746814    0.203057217395088  [0, 3, 6]
#     5               0.212407727049186  0.202900735525672  [0, 3, 6]
#
# Mean RMSE for "Linear Regression Model": 2.5449863754256654
# Median RMSE for "Linear Regression Model": 0.5081500592358804
# Mean RMSE for "Mean Model": 0.2018734455629275
# Median RMSE for "Mean Model": 0.202318803532519
#
# Validate for these predictors: 'day_index', 'mo', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.41256258780932   [0, 3, 6]
#     2       0.183606685066288  [0, 3, 6]
#     3       0.587165101666932  [0, 3, 6]
#     4       9.43477653692897   [0, 3, 6]
#     5       0.156086919588161  [0, 3, 6]
#
# Mean RMSE for Validaton Data: 2.1548395662119333
# Median RMSE for Validaton Data: 0.4125625878093203
#
# -------
#
# Model for these predictors: 'day_index', 'mo', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               7.74906190154557   0.202159318286349  [0, 3, 7]
#     2               0.52990594905986   0.203981218683613  [0, 3, 7]
#     3               0.215036107176784  0.206693598544935  [0, 3, 7]
#     4               0.214651832585675  0.202136945418771  [0, 3, 7]
#     5               0.609141615770308  0.204666223917289  [0, 3, 7]
#
# Mean RMSE for "Linear Regression Model": 1.8635594812276395
# Median RMSE for "Linear Regression Model": 0.5299059490598603
# Mean RMSE for "Mean Model": 0.20392746097019115
# Median RMSE for "Mean Model": 0.20398121868361288
#
# Validate for these predictors: 'day_index', 'mo', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       6.6246720759743    [0, 3, 7]
#     2       0.423904173855848  [0, 3, 7]
#     3       0.14879313430509   [0, 3, 7]
#     4       0.122570330928615  [0, 3, 7]
#     5       0.52663210819232   [0, 3, 7]
#
# Mean RMSE for Validaton Data: 1.569314364651234
# Median RMSE for Validaton Data: 0.4239041738558476
#
# -------
#
# Model for these predictors: 'day_index', 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.940082248554617  0.205118693511375  [0, 5, 6]
#     2               0.630089790595004  0.20349663752709   [0, 5, 6]
#     3               3.94051743475771   0.202167050640898  [0, 5, 6]
#     4               1.76143426449965   0.205290046691555  [0, 5, 6]
#     5               0.388457473954396  0.198794999081221  [0, 5, 6]
#
# Mean RMSE for "Linear Regression Model": 1.532116242472274
# Median RMSE for "Linear Regression Model": 0.9400822485546173
# Mean RMSE for "Mean Model": 0.20297348549042799
# Median RMSE for "Mean Model": 0.20349663752709024
#
# Validate for these predictors: 'day_index', 'temp', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.775305597284807  [0, 5, 6]
#     2       0.541396459037218  [0, 5, 6]
#     3       3.41103406711157   [0, 5, 6]
#     4       1.56520018295628   [0, 5, 6]
#     5       0.337508247574394  [0, 5, 6]
#
# Mean RMSE for Validaton Data: 1.3260889107928533
# Median RMSE for Validaton Data: 0.7753055972848067
#
# -------
#
# Model for these predictors: 'day_index', 'temp', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.256788000362344  0.206067891716148  [0, 5, 7]
#     2               0.43915180777753   0.204286510196211  [0, 5, 7]
#     3               0.221917781653763  0.206062695913604  [0, 5, 7]
#     4               0.462251044048003  0.20397707278431   [0, 5, 7]
#     5               2.24939781560281   0.200991913471241  [0, 5, 7]
#
# Mean RMSE for "Linear Regression Model": 0.7259012898888894
# Median RMSE for "Linear Regression Model": 0.43915180777753027
# Mean RMSE for "Mean Model": 0.20427721681630268
# Median RMSE for "Mean Model": 0.20428651019621083
#
# Validate for these predictors: 'day_index', 'temp', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.219193897973554  [0, 5, 7]
#     2       0.376933125757386  [0, 5, 7]
#     3       0.168009992846267  [0, 5, 7]
#     4       0.361807237628022  [0, 5, 7]
#     5       1.93834384457107   [0, 5, 7]
#
# Mean RMSE for Validaton Data: 0.6128576197552599
# Median RMSE for Validaton Data: 0.3618072376280216
#
# -------
#
# Model for these predictors: 'day_index', 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.207087151820023  0.201742903129166  [0, 6, 7]
#     2               0.268342556861157  0.204014653062011  [0, 6, 7]
#     3               1.71265479550454   0.205501462983238  [0, 6, 7]
#     4               0.324125827847098  0.198433314960177  [0, 6, 7]
#     5               0.269069938687854  0.204805460166349  [0, 6, 7]
#
# Mean RMSE for "Linear Regression Model": 0.5562560541441337
# Median RMSE for "Linear Regression Model": 0.26906993868785434
# Mean RMSE for "Mean Model": 0.20289955886018823
# Median RMSE for "Mean Model": 0.2040146530620111
#
# Validate for these predictors: 'day_index', 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.130927757845624  [0, 6, 7]
#     2       0.216698646703242  [0, 6, 7]
#     3       1.41192884197585   [0, 6, 7]
#     4       0.292122859709896  [0, 6, 7]
#     5       0.180795279907629  [0, 6, 7]
#
# Mean RMSE for Validaton Data: 0.4464946772284474
# Median RMSE for Validaton Data: 0.2166986467032418
#
# -------
#
# Model for these predictors: 'day', 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               3.24339291076038   0.202976691836461  [1, 2, 6]
#     2               9.73362492360699   0.205455998306927  [1, 2, 6]
#     3               0.797202812372364  0.199475565831003  [1, 2, 6]
#     4               0.30258613695315   0.201990295147542  [1, 2, 6]
#     5               0.240130682972997  0.202238084697771  [1, 2, 6]
#
# Mean RMSE for "Linear Regression Model": 2.8633874933331764
# Median RMSE for "Linear Regression Model": 0.7972028123723643
# Mean RMSE for "Mean Model": 0.20242732716394052
# Median RMSE for "Mean Model": 0.2022380846977712
#
# Validate for these predictors: 'day', 'year', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       3.19533176399824   [1, 2, 6]
#     2       9.71755999456999   [1, 2, 6]
#     3       0.76499922939285   [1, 2, 6]
#     4       0.310621478774275  [1, 2, 6]
#     5       0.188519360524608  [1, 2, 6]
#
# Mean RMSE for Validaton Data: 2.835406365451992
# Median RMSE for Validaton Data: 0.76499922939285
#
# -------
#
# Model for these predictors: 'day', 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
# Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.
#
# -------
#
# Model for these predictors: 'day', 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.631356116473893  0.205019062704202  [1, 3, 5]
#     2               0.205690928531493  0.204032628912557  [1, 3, 5]
#     3               0.356570553798882  0.204597831590826  [1, 3, 5]
#     4               0.20789334670072   0.201108782527501  [1, 3, 5]
#     5               0.308239119065859  0.20388824044844   [1, 3, 5]
#
# Mean RMSE for "Linear Regression Model": 0.3419500129141695
# Median RMSE for "Linear Regression Model": 0.30823911906585905
# Mean RMSE for "Mean Model": 0.2037293092367051
# Median RMSE for "Mean Model": 0.2040326289125572
#
# Validate for these predictors: 'day', 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.536663598612223  [1, 3, 5]
#     2       0.141062930084072  [1, 3, 5]
#     3       0.303369114937588  [1, 3, 5]
#     4       0.180363937536181  [1, 3, 5]
#     5       0.255433368269009  [1, 3, 5]
#
# Mean RMSE for Validaton Data: 0.2833785898878145
# Median RMSE for Validaton Data: 0.2554333682690092
#
# -------
#
# Model for these predictors: 'day', 'mo', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.238418870258109  0.204478468516956  [1, 3, 6]
#     2               0.212274433205128  0.205760378480559  [1, 3, 6]
#     3               0.209366170314496  0.201155727932119  [1, 3, 6]
#     4               0.210016908884012  0.204223570422752  [1, 3, 6]
#     5               0.20969229035877   0.198581511848922  [1, 3, 6]
#
# Mean RMSE for "Linear Regression Model": 0.21595373460410286
# Median RMSE for "Linear Regression Model": 0.21001690888401217
# Mean RMSE for "Mean Model": 0.20283993144026152
# Median RMSE for "Mean Model": 0.20422357042275188
#
# Validate for these predictors: 'day', 'mo', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.184856034047246  [1, 3, 6]
#     2       0.170995866648719  [1, 3, 6]
#     3       0.128410690059495  [1, 3, 6]
#     4       0.109753835342525  [1, 3, 6]
#     5       0.158077685078509  [1, 3, 6]
#
# Mean RMSE for Validaton Data: 0.1504188222352989
# Median RMSE for Validaton Data: 0.15807768507850936
#
# -------
#
# Model for these predictors: 'day', 'mo', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.215823884050258  0.205482695100693  [1, 3, 7]
#     2               0.229274380256483  0.201982370793408  [1, 3, 7]
#     3               0.238470840797335  0.207114476277247  [1, 3, 7]
#     4               0.225094919163774  0.204068841239114  [1, 3, 7]
#     5               0.202911633675602  0.200884836537405  [1, 3, 7]
#
# Mean RMSE for "Linear Regression Model": 0.2223151315886903
# Median RMSE for "Linear Regression Model": 0.22509491916377355
# ...
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 100 |  2.25638508935604  |     0.204970995958602 | day          |       5 |   2.2908832016135   |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 101 |  2.36980769354804  |     0.205363322993823 | day_index    |       5 |   2.0764404442145   |            5 |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 102 |  2.41588508981282  |     0.202541650680223 | day          |       5 |   2.42093311276381  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 103 |  2.54975951167345  |     0.203471423899924 | day_index    |       5 |   2.49969918096225  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 104 |  2.94128248664002  |     0.203470749123737 | year         |       5 |   2.9639639867455   |            5 |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 105 |  2.9566226396111   |     0.202865686466009 | year         |       5 |   2.91523702205085  |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 106 |  3.20168877868448  |     0.204259568350927 | day          |       5 |   3.21157186436925  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 107 |  3.24841757702284  |     0.202589551737232 | day          |       5 |   3.2027642643458   |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 108 |  3.31230689808181  |     0.202822304431627 | day          |       5 |   3.28197213671931  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 109 |  3.3327819098182   |     0.202176916744878 | day_index    |       5 |   3.38386366420515  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 110 |  3.52643766949372  |     0.203415773174404 | day_index    |       5 |   3.36949179471543  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 111 |  3.57222639751069  |     0.20387808373225  | day_index    |       5 |   3.33356785821725  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 112 |  3.75513740236111  |     0.204120735261585 | year         |       5 |   3.75322181234088  |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 113 |  3.99495844848296  |     0.203042184446637 | year         |       5 |   4.03243934408132  |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 114 |  4.12651158307522  |     0.203686215198735 | day_index    |       5 |   3.87184093615664  |            5 |
# |     |                    |                       | year         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 115 |  4.21961951749506  |     0.2047637104123   | day_index    |       5 |   4.03674474645996  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 116 |  4.31793063320904  |     0.205098833765385 | year         |       5 |   4.29954482555567  |            5 |
# |     |                    |                       | mo           |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 117 |  4.41809251138015  |     0.204629730806448 | year         |       5 |   4.38639111245889  |            5 |
# |     |                    |                       | temp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 118 |  4.52325122854121  |     0.204191958739701 | year         |       5 |   4.52201060285677  |            5 |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 119 |  4.54650308348549  |     0.203547281989282 | day_index    |       5 |   4.20750564362455  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 120 |  4.7895568112441   |     0.201656221210007 | day_index    |       5 |   4.63108537762551  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 121 |  6.15331840644941  |     0.202343332032036 | day_index    |       5 |   5.78111217514305  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 122 |  7.26910005262174  |     0.207864611331586 | day          |       5 |   7.33020270273223  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 123 |  8.49803922544001  |     0.206489060862494 | day          |       5 |   8.45239190900011  |            5 |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 124 |  8.96705502044279  |     0.203528888106757 | year         |       5 |   8.98530408188499  |            5 |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 125 |  9.8753867318389   |     0.204939006996775 | day_index    |       5 |   8.67304282687137  |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | temp         |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+
# | 126 | 10.8705978514946   |     0.204647784008687 | day_index    |       5 |  10.6045836248596   |            5 |
# |     |                    |                       | day          |         |                     |              |
# |     |                    |                       | year         |         |                     |              |
# |     |                    |                       | mo           |         |                     |              |
# |     |                    |                       | visib        |         |                     |              |
# |     |                    |                       | wdsp         |         |                     |              |
# +-----+--------------------+-----------------------+--------------+---------+---------------------+--------------+

# %%
# print all results in memory from all runs (optional)
print(all_rmse_results)
# Out:
# [{'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 0.2437123288081831, 'Mean Model RMSE': 0.20467063063095553, 'Predictors Columns': [0]}, {'Run': 2, 'Linear Regression Model RMSE': 3.8284787601574473, 'Mean Model RMSE': 0.20142648856989984, 'Predictors Columns': [0]}, {'Run': 3, 'Linear Regression Model RMSE': 0.2732813309734949, 'Mean Model RMSE': 0.2033515472686377, 'Predictors Columns': [0]}, {'Run': 4, 'Linear Regression Model RMSE': 1.2520204265924961, 'Mean Model RMSE': 0.20059965737481317, 'Predictors Columns': [0]}, {'Run': 5, 'Linear Regression Model RMSE': 0.3354197387364066, 'Mean Model RMSE': 0.20239909808027182, 'Predictors Columns': [0]}], 'validation_results': [{'Run': 1, 'Validation Test RMSE': 0.10746407829585823, 'Predictors Columns': [0]}, {'Run': 2, 'Validation Test RMSE': 3.1984033939359664, 'Predictors Columns': [0]}, {'Run': 3, 'Validation Test RMSE': 0.22992423382345611, 'Predictors Columns': [0]}, {'Run': 4, 'Validation Test RMSE': 1.0397512945158154, 'Predictors Columns': [0]}, {'Run': 5, 'Validation Test RMSE': 0.27349895292273074, 'Predictors Columns': [0]}]}, {'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 0.22136489798254497, 'Mean Model RMSE': 0.2038021048004812, 'Predictors Columns': [1]}, {'Run': 2, 'Linear Regression Model RMSE': 0.24853998907717964, 'Mean Model RMSE': 0.20810019049002243, 'Predictors Columns': [1]}, {'Run': 3, 'Linear Regression Model RMSE': 0.2019146076957643, 'Mean Model RMSE': 0.19990866826972986, 'Predictors Columns': [1]}, {'Run': 4, 'Linear Regression Model RMSE': 0.20830506501889787, 'Mean Model RMSE': 0.20134603494856196, 'Predictors Columns': [1]}, {'Run': 5, 'Linear Regression Model RMSE': 0.20610756481533551, 'Mean Model RMSE': 0.20398479649894752, 'Predictors Columns': [1]}], 'validation_results': [{'Run': 1, 'Validation Test RMSE': 0.17260433838032782, 'Predictors Columns': [1]}, {'Run': 2, 'Validation Test RMSE': 0.1919244863986191, 'Predictors Columns': [1]}, {'Run': 3, 'Validation Test RMSE': 0.15696728737665094, 'Predictors Columns': [1]}, {'Run': 4, 'Validation Test RMSE': 0.15378077011440167, 'Predictors Columns': [1]}, {'Run': 5, 'Validation Test RMSE': 0.15057557974192112, 'Predictors Columns': [1]}]}, {'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 14.55400938432807, 'Mean Model RMSE': 0.20589064668030013, 'Predictors Columns': [2]}, {'Run': 2, 'Linear Regression Model RMSE': 1.564196239344679, 'Mean Model RMSE': 0.19817798532937606, 'Predictors Columns': [2]}, {'Run': 3, 'Linear Regression Model RMSE': 7.194857989235991, 'Mean Model RMSE': 0.2021623172398577, 'Predictors Columns': [2]}, {'Run': 4, 'Linear Regression Model RMSE': 0.8364313720441082, 'Mean Model RMSE': 0.2047747864596406, 'Predictors Columns': [2]}, {'Run': 5, 'Linear Regression Model RMSE': 1.4593322881945698, 'Mean Model RMSE': 0.20308454643029952, 'Predictors Columns': [2]}], 'validation_results': [{'Run': 1, 'Validation Test RMSE': 14.553592991490445, 'Predictors Columns': [2]}, {'Run': 2, 'Validation Test RMSE': 1.5536447018551398, 'Predictors Columns': [2]}, {'Run': 3, 'Validation Test RMSE': 7.198027831149635, 'Predictors Columns': [2]}, {'Run': 4, 'Validation Test RMSE': 0.8142679147275886, 'Predictors Columns': [2]}, {'Run': 5, 'Validation Test RMSE': 1.4475233947360069, 'Predictors Columns': [2]}]}, {'model_results': [{'Run': 1, 'Linear Regression Model RMSE': 0.20788616687183925, 'Mean Model RMSE': 0.2066982384211334, 'Predictors Columns': [3]}, {'Run': 2, 'Linear Regression Model RMSE': 0.21118278640189744, 'Mean Model RMSE': 0.2049387722751914, 'Predictors Columns': [3]}, {'Run': 3, 'Linear Regression Model RMSE': 0.20833036114336076, 'Mean Model RMSE': 0.20187602101257027, 'Predictors Columns': [3]}, {'Run': 4, 'Linear Regression Model RMSE': 0.22150467903026913, 'Mean Model RMSE': 0.2080026442873231, 'Predictors Columns': [3]}, {'Run': 5, 'Linear Regression Model RMSE': 0.20751202025151028, 'Mean Model RMSE': 0.20565650995679258, 'Pr ...
