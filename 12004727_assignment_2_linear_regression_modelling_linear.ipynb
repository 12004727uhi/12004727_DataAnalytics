# %% [markdown]
# <a href="https://colab.research.google.com/github/12004727uhi/12004727_DataAnalytics/blob/master/12004727_assignment_2_linear_regression_modelling_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas, to create data frame
import pandas as pd
# import numpy for maths operations
import numpy as np
# import tensorflow for modelling
# %tensorflow_version 1.x
import tensorflow as tf
# import file management utilities
import shutil
# import package to create data tables
from tabulate import tabulate
# import iterable tools
import itertools
# Out:
# TensorFlow 1.x selected.

# %%
## Configuration
#
# enable logging for tensorflow (set to ERROR when automating, or INFO for diagnostic)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# define dataset friendly name (descriptive)
DATASET_TITLE = '2013 to 2019 [linear_1.csv]'
# define dataset csv name
DATASET_NAME = 'linear_1'
# define dataset CSV URL
DATA_URL = 'https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/linear_1.csv'
# define validation dataset CSV URL
VALIDATION_DATA_URL = 'https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/sample_linear_1.csv'
# import dataset CSV & assign to variable (type pandas df)
TRAIN_AND_TEST_DATA = pd.read_csv(DATA_URL, index_col=0,)
# import validation dataset CSV & assign to variable (type pandas df)
VALIDATION_DATA = pd.read_csv(VALIDATION_DATA_URL, index_col=0,)
# define number of targets
NUM_TARGETS = 1
# define predictors for training/testing
predictor_column_list = [0,1,2,3,4,5,6]
predictors = []
for idx, predictor in enumerate(predictor_column_list, 1):
  predictors.append([list(p) for p in itertools.combinations(predictor_column_list, idx)])
  pred = [list(p) for p in itertools.combinations(predictor_column_list, idx)]
PREDICTORS_COLS = list(itertools.chain(*predictors))
# define target column indexes
TARGETS_COLS = [7]
# define validation target column name(s)
VALIDATION_TARGETS = ['NUM_COLLISIONS']
# URI of model
MODEL_URI = f'/tmp/trained_model_{DATASET_NAME}'
# define how many model runs for training & testing
NUMBER_OF_MODEL_RUNS = 5
# Define scale parameter for number of collisions
SCALE_NUM_COLLISIONS = 1.0
# define number of estimator fit steps
ESTIMATOR_STEPS = 10000
# define model learning rate
LEARNING_RATE = 0.01 # default 0.1
# set training set size (percentage as decimal)
TRAINING_SET_SLICE = 0.8

# show first 5 rows to verify import
display(TRAIN_AND_TEST_DATA[:5])
# show first 5 rows to verify import
display(VALIDATION_DATA[:5])
# print length of predictors column list to verify
print(f'Predictors columns: {len(PREDICTORS_COLS)}')
# check the tensorflow version
print(f'Tensor flow version: {tf.__version__}')
# Out:
#     day_index  day  year  mo  temp  visib  wdsp  NUM_COLLISIONS
# 44          1    2  2013   1  35.4    2.6   4.9        0.365234
# 47          2    7  2013   1  45.4    4.3   5.8        0.035156
# 50          3    3  2013   1  39.9    6.8   5.3        0.257812
# 54          4    5  2013   1  38.0   10.0   5.4        0.595703
# 68          5    6  2013   1  42.7    7.1   7.9        0.234375
#       day_index  day  year  mo  temp  visib  wdsp  NUM_COLLISIONS
# 682          76    3  2013   3  46.3    7.1  13.1        0.548828
# 1775       2023    1  2018   7  60.9   10.0   6.7        0.618705
# 2522       1000    1  2015   9  67.6   10.0  14.5        0.486708
# 705        1177    3  2016   3  43.4   10.0  13.2        0.562130
# 3127        706    3  2014  12  26.9    9.9   7.5        0.261161
# Predictors columns: 127
# Tensor flow version: 1.15.2

# %%
# define function to create table of training/testing results & compute RSME
def create_results_table(rmse_results):
  # calculate mean & median RMSEs
  regression_RMSE_list = [n['Linear Regression Model RMSE'] for n in rmse_results]
  mean_model_RMSE_list = [n['Mean Model RMSE'] for n in rmse_results]
  regression_mean_RMSE = np.mean(regression_RMSE_list)
  mean_mean_RMSE = np.mean(mean_model_RMSE_list)
  regression_median_RMSE = np.median(regression_RMSE_list)
  mean_median_RMSE = np.median(mean_model_RMSE_list)
  header = rmse_results[0].keys()
  rows =  [x.values() for x in rmse_results]
  # ONLY PRINT OUTPUT IF regression_median_RMSE <= 1.0
  if regression_median_RMSE < 1.0:
    print(tabulate(rows, header, floatfmt=".15"))
    # print mean & median RMSEs
    print(f'\nMean RMSE for "Linear Regression Model": {regression_mean_RMSE}')
    print(f'Median RMSE for "Linear Regression Model": {regression_median_RMSE}')
    print(f'Mean RMSE for "Mean Model": {mean_mean_RMSE}')
    print(f'Median RMSE for "Mean Model": {mean_median_RMSE}\n')
    return True
  else:
    print(f'Median Linear Regressor RMSE was value was over 1.0! Tables will not be drawn.')
    return False

# %%
# function to create table of validation results & compute RSME
def create_validation_table(validation_results):
  header = validation_results[0].keys()
  rows =  [x.values() for x in validation_results]
  # print table
  print(tabulate(rows, header, floatfmt=".15"))
  # calculate mean & median RMSEs
  validation_RMSE_list = [n['Validation Test RMSE'] for n in validation_results]
  validation_mean_RMSE = np.mean(validation_RMSE_list)
  validation_median_RMSE = np.median(validation_RMSE_list)
  # print mean & median RMSEs
  print(f'\nMean RMSE for Validaton Data: {validation_mean_RMSE}')
  print(f'Median RMSE for Validaton Data: {validation_median_RMSE}')

# %%
# function to generate rank table of median rmse result over n runs
def create_rank_table(all_results):
  # define final table lists
  table_list = []
  # compile table list with medians 
  for model in all_results:
    run_rmse_list = [run['Linear Regression Model RMSE'] for run in model['model_results']]
    run_mean_model_rmse_list = [run['Mean Model RMSE'] for run in model['model_results']]
    run_validation_rmse_list = [run['Validation Test RMSE'] for run in model['validation_results']]
    table_list.append({'Median RMSE\n(Ranked)': np.median(run_rmse_list), 
                       'Median \'Mean Model\'\nRMSE': np.median(run_mean_model_rmse_list),
                       'Model\nPredictors': '\n'.join([TRAIN_AND_TEST_DATA.columns[c] for c in model['model_results'][0]['Predictors Columns']]),
                       'Model\nRuns': len(run_rmse_list),
                       'Median Validation\nRMSE': np.median(run_validation_rmse_list),
                       'Validation\nRuns': len(run_validation_rmse_list)
                       })
  # rank medians
  sorted_table_list = sorted(table_list, key=lambda d: d['Median RMSE\n(Ranked)'])
  # display table
  print('\n----------------------------------------------------------------')
  print('Ranked Table of Median RMSE Results for Linear Regression Models')
  print('----------------------------------------------------------------')
  print('Tensor Flow Linear Regression Output')
  print(f'Model dataset title: {DATASET_TITLE}')
  print(f'Model dataset CSV: {DATA_URL}')
  print(f'Model validation dataset CSV: {VALIDATION_DATA_URL}\n')
  header = sorted_table_list[0].keys()
  rows =  [x.values() for x in sorted_table_list]
  print(tabulate(rows, header, floatfmt=".15", showindex='always', tablefmt="grid"))

# %%
## define function to validate against normalised, processed dataset
# set pandas to display _all_ columns
pd.set_option('display.max_columns', None)
def run_validation(validation_predictors_cols):
  # shuffle data
  shuffled_validation_data = VALIDATION_DATA.iloc[np.random.permutation(len(VALIDATION_DATA))]
  # assign predictors to variables
  predictors_validation_data = shuffled_validation_data.iloc[:,validation_predictors_cols]
  # define TensorFlow estimator
  estimator = tf.contrib.learn.SKCompat(tf.contrib.learn.LinearRegressor(model_dir=MODEL_URI, enable_centered_bias=False, feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors_validation_data.values)))
  # check predictions based on defined predictors and assign result to variable
  validation_predictions = estimator.predict(x=predictors_validation_data.values)
  # extract a list of the resulting prediction scores
  validation_prediction_scores = validation_predictions['scores']
  # define validation data targets
  targets_validation = pd.DataFrame(list(VALIDATION_DATA[t] for t in VALIDATION_TARGETS))
  # calculate RMSE for regression model and actual validation collision data
  validation_rmse = np.sqrt(np.mean((targets_validation.values - validation_prediction_scores)**2))
  # return  results
  return validation_rmse

# %%
# function to generate table of validation results
def gen_validation_results_table(validation_result_list):
  create_validation_table(validation_result_list)

# function to generate table of results
def gen_results_table(rmse_result_list):
  return create_results_table(rmse_result_list)

# function to do validation
def do_validation(predictors_combination):
  return run_validation(predictors_combination)
  
# function to loop linear regressor n times (shuffling data each time). Returns dict of RMSE results.
def run_linear_regressor(predictors_cols):
  # define result lists to return
  result_list = []
  validation_result_list = []
  for idx, run in enumerate(range(NUMBER_OF_MODEL_RUNS)):
    # shuffle data & print first 5 rows
    shuffled = TRAIN_AND_TEST_DATA.iloc[np.random.permutation(len(TRAIN_AND_TEST_DATA))]
    # assign predictors to variable
    predictors = shuffled.iloc[:,predictors_cols]
    # assign targets to variable
    targets = shuffled.iloc[:,TARGETS_COLS]
    # define training set size - 80% of the shuffled data array length
    training_set_size = int(len(shuffled['NUM_COLLISIONS'])*TRAINING_SET_SLICE)
    # define test set size - the remaining of the shuffled data array length
    test_set_size = len(shuffled['NUM_COLLISIONS']) - training_set_size
    # Define number of targets (outputs)
    num_of_targets = NUM_TARGETS
    # ensure any previously saved training run models are removed
    shutil.rmtree(MODEL_URI, ignore_errors=True)
    # define the TensorFlow estimator
    estimator = tf.contrib.learn.SKCompat(
        tf.contrib.learn.LinearRegressor(
            model_dir=MODEL_URI, 
            optimizer=tf.train.AdamOptimizer(learning_rate=LEARNING_RATE), 
            enable_centered_bias=False, 
            feature_columns=tf.contrib.learn.infer_real_valued_columns_from_input(predictors.values) 
            )
        )
    # train the model, using previously defined predictor & target values
    estimator.fit(predictors[:training_set_size].values, 
                  targets[:training_set_size].values.reshape(
                      training_set_size, num_of_targets)/SCALE_NUM_COLLISIONS, steps=ESTIMATOR_STEPS
                  )
    # check predictions based on defined predictors and assign result to variable
    predictions = estimator.predict(x=predictors[training_set_size:].values)
    # Apply scaling to output (not require here as previously discussed)
    predictions_scaled = predictions['scores']*SCALE_NUM_COLLISIONS
    # format predictions as strings to make readable in printing to check output etc
    predictions_formatted = format(str(predictions_scaled))
    # calculate RSME to determine how well the model is predicting the targets from the predictors
    rmse_linear_model = np.sqrt(np.mean((targets[training_set_size:].values - predictions_scaled)**2))
    # calculate mean of the normalised collision values
    mean_norm_collisions = np.mean(shuffled['NUM_COLLISIONS'][:training_set_size])
    # calculate the RMSE of line of best fit that simply follows a mean of target values.
    # This allows comparison between the 'mean model' and the proposed linear regression model.
    # If the linear regression model is successful, it will show a 'better fit' than the 'mean model'
    # i.e., the resulting calculation should be *lower*.
    rmse_mean_model = np.sqrt(np.mean((shuffled['NUM_COLLISIONS'][training_set_size:] - mean_norm_collisions)**2))
    # add rmse calculations to result list
    result_list.append({'Run': idx+1, 'Linear Regression Model RMSE': rmse_linear_model, 'Mean Model RMSE': rmse_mean_model, 'Predictors Columns': predictors_cols})
    # perform validation process
    validation_result_list.append({'Run': idx+1, 'Validation Test RMSE' : do_validation(predictors_cols), 'Predictors Columns': predictors_cols})
  # draw table
  model_table_generated = gen_results_table(result_list)
  # draw validation table results table only if model table was also drawn
  if model_table_generated:
    print('Validate for these predictors: {}'.format(", ".join(f"\'{VALIDATION_DATA.columns[c]}\'" for c in predictors_cols)))
    print('Validate for these targets: {}\n'.format(", ".join(f"\'{t}\'" for t in VALIDATION_TARGETS)))
    gen_validation_results_table(validation_result_list)
  # return results
  return [result_list, validation_result_list]

# %%
# - run all models n times, for all predictor combinations on imported datasets;
# - calculate & tabulate RMSEs for each model run & then calculate mean RMSE;
# - run model n time on validation datasets, for all predictor combinations;
# - calculate RMSE for each model validation run & then calculate mean RMSE;

# function to do modelling & validation
def model_and_validate():
  # define list to retain all results in memory for further analysis if necessary
  all_rmse_results = []
  # print sheet header
  print(f'Tensor Flow Linear Regression Output')
  print(f'Model dataset title: {DATASET_TITLE}')
  print(f'Model dataset CSV: {DATA_URL}')
  print(f'Model validation dataset CSV: {VALIDATION_DATA_URL}')
  print(f'------------------------------------------------------------------------------\n')
  for predictors_combination in PREDICTORS_COLS:
    # print the predictor combination
    print('Model for these predictors: {}'.format(", ".join(f"\'{TRAIN_AND_TEST_DATA.columns[c]}\'" for c in predictors_combination)))
    print('Model for these targets: {}\n'.format(", ".join(f"\'{TRAIN_AND_TEST_DATA.columns[t]}\'" for t in TARGETS_COLS)))
    results = run_linear_regressor(predictors_combination)
    # add results to in-memory list
    all_rmse_results.append({'model_results': results[0], 'validation_results': results[1]})
    print(f'\n-------\n')
  # generate rank table of median rmse result over n runs
  generate_rank_table(all_rmse_results)
  return all_rmse_results

# function to generate rank table of results
def generate_rank_table(all_results):
  create_rank_table(all_results)
  
all_rmse_results = model_and_validate()
# Out:
# Tensor Flow Linear Regression Output
# Model dataset title: 2013 to 2019 [linear_1.csv]
# Model dataset CSV: https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/linear_1.csv
# Model validation dataset CSV: https://raw.githubusercontent.com/12004727uhi/12004727_DataAnalytics/master/sample_linear_1.csv
# ------------------------------------------------------------------------------
#
# Model for these predictors: 'day_index'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.198865842495405  0.18869727919682   [0]
#     2               0.207108701203428  0.175112975434292  [0]
#     3               0.487658847027225  0.181240807783914  [0]
#     4               0.353969552863136  0.199281894615111  [0]
#     5               0.225297490437686  0.193369179231538  [0]
#
# Mean RMSE for "Linear Regression Model": 0.2945800868053762
# Median RMSE for "Linear Regression Model": 0.22529749043768624
# Mean RMSE for "Mean Model": 0.18754042725233494
# Median RMSE for "Mean Model": 0.1886972791968203
#
# Validate for these predictors: 'day_index'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.197738138489611  [0]
#     2       0.201583677594887  [0]
#     3       0.504074037026643  [0]
#     4       0.30349245557675   [0]
#     5       0.179833096898355  [0]
#
# Mean RMSE for Validaton Data: 0.2773442811172492
# Median RMSE for Validaton Data: 0.20158367759488663
#
# -------
#
# Model for these predictors: 'day'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.18872100855504   0.181719787371247  [1]
#     2               0.199729042412255  0.190143995746795  [1]
#     3               0.208972213825756  0.198787828404703  [1]
#     4               0.196431002125861  0.18570150731802   [1]
#     5               0.197183503940243  0.186718729805142  [1]
#
# Mean RMSE for "Linear Regression Model": 0.19820735417183072
# Median RMSE for "Linear Regression Model": 0.1971835039402429
# Mean RMSE for "Mean Model": 0.18861436972918155
# Median RMSE for "Mean Model": 0.18671872980514242
#
# Validate for these predictors: 'day'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.147686457519129  [1]
#     2       0.162276758609036  [1]
#     3       0.16997097076941   [1]
#     4       0.176406218404819  [1]
#     5       0.191064042099999  [1]
#
# Mean RMSE for Validaton Data: 0.16948088948047824
# Median RMSE for Validaton Data: 0.16997097076940967
#
# -------
#
# Model for these predictors: 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.741152968489668  0.18232816437127   [2]
#     2               0.567505167931417  0.188423232450449  [2]
#     3               0.297763229654477  0.194012978139042  [2]
#     4               1.56223383585258   0.19091842278793   [2]
#     5               0.189400564152858  0.17779998671428   [2]
#
# Mean RMSE for "Linear Regression Model": 0.6716111532162011
# Median RMSE for "Linear Regression Model": 0.567505167931417
# Mean RMSE for "Mean Model": 0.18669655689259415
# Median RMSE for "Mean Model": 0.1884232324504486
#
# Validate for these predictors: 'year'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.724506114567279  [2]
#     2       0.567871107483669  [2]
#     3       0.303056758105151  [2]
#     4       1.55601020809556   [2]
#     5       0.185521899019704  [2]
#
# Mean RMSE for Validaton Data: 0.6673932174542736
# Median RMSE for Validaton Data: 0.5678711074836686
#
# -------
#
# Model for these predictors: 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.194294326556438  0.191270104243018  [3]
#     2               0.195785253119394  0.192172316874013  [3]
#     3               0.193520926623805  0.18886718884122   [3]
#     4               0.190769869349947  0.185817451492881  [3]
#     5               0.191370330827783  0.185877426293344  [3]
#
# Mean RMSE for "Linear Regression Model": 0.19314814129547356
# Median RMSE for "Linear Regression Model": 0.19352092662380452
# Mean RMSE for "Mean Model": 0.18880089754889526
# Median RMSE for "Mean Model": 0.18886718884122
#
# Validate for these predictors: 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.168479262992232  [3]
#     2       0.158242594850998  [3]
#     3       0.178320575994959  [3]
#     4       0.182227958174618  [3]
#     5       0.183120792096678  [3]
#
# Mean RMSE for Validaton Data: 0.17407823682189688
# Median RMSE for Validaton Data: 0.17832057599495865
#
# -------
#
# Model for these predictors: 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.193091510364626  0.185380549646335  [4]
#     2               0.190434114509053  0.184615015822439  [4]
#     3               0.18634718299653   0.18138593400517   [4]
#     4               0.196223135504858  0.191412395125477  [4]
#     5               0.203824739509252  0.195016401929438  [4]
#
# Mean RMSE for "Linear Regression Model": 0.19398413657686364
# Median RMSE for "Linear Regression Model": 0.19309151036462552
# Mean RMSE for "Mean Model": 0.18756205930577177
# Median RMSE for "Mean Model": 0.18538054964633485
#
# Validate for these predictors: 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.170264861137446  [4]
#     2       0.178499775023786  [4]
#     3       0.159664252712524  [4]
#     4       0.185422747123164  [4]
#     5       0.170217315372126  [4]
#
# Mean RMSE for Validaton Data: 0.17281379027380905
# Median RMSE for Validaton Data: 0.17026486113744582
#
# -------
#
# Model for these predictors: 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.189907713774545  0.188844298822587  [5]
#     2               0.19036689622393   0.189803400442492  [5]
#     3               0.206020490374599  0.19252707375973   [5]
#     4               0.192592329889903  0.190391467772302  [5]
#     5               0.18807238007174   0.18116190668044   [5]
#
# Mean RMSE for "Linear Regression Model": 0.19339196206694348
# Median RMSE for "Linear Regression Model": 0.19036689622393033
# Mean RMSE for "Mean Model": 0.18854562949551018
# Median RMSE for "Mean Model": 0.18980340044249222
#
# Validate for these predictors: 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.171521985945806  [5]
#     2       0.17054889213214   [5]
#     3       0.18160301197247   [5]
#     4       0.176722185324784  [5]
#     5       0.176382699336592  [5]
#
# Mean RMSE for Validaton Data: 0.17535575494235855
# Median RMSE for Validaton Data: 0.17638269933659234
#
# -------
#
# Model for these predictors: 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.184720537381655  0.185237783993721  [6]
#     2               0.18709506678917   0.186431924943278  [6]
#     3               0.183403740720282  0.182835408763338  [6]
#     4               0.192880267239716  0.189021674862698  [6]
#     5               0.191505673670435  0.190973798037103  [6]
#
# Mean RMSE for "Linear Regression Model": 0.18792105716025162
# Median RMSE for "Linear Regression Model": 0.18709506678916996
# Mean RMSE for "Mean Model": 0.1869001181200278
# Median RMSE for "Mean Model": 0.18643192494327826
#
# Validate for these predictors: 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.172412892822706  [6]
#     2       0.168351545936596  [6]
#     3       0.173318327777174  [6]
#     4       0.17261924985483   [6]
#     5       0.176338007342036  [6]
#
# Mean RMSE for Validaton Data: 0.1726080047466685
# Median RMSE for Validaton Data: 0.17261924985483038
#
# -------
#
# Model for these predictors: 'day_index', 'day'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.203883857150886  0.182777268759486  [0, 1]
#     2               0.199375254220707  0.186872564944498  [0, 1]
#     3               0.357860575860942  0.18214151884321   [0, 1]
#     4               0.425608602426888  0.185563180072625  [0, 1]
#     5               0.261433339214209  0.180865085439921  [0, 1]
#
# Mean RMSE for "Linear Regression Model": 0.28963232577472653
# Median RMSE for "Linear Regression Model": 0.2614333392142091
# Mean RMSE for "Mean Model": 0.18364392361194798
# Median RMSE for "Mean Model": 0.18277726875948602
#
# Validate for these predictors: 'day_index', 'day'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.137680469476794  [0, 1]
#     2       0.18429661618715   [0, 1]
#     3       0.413864071031078  [0, 1]
#     4       0.411681994804937  [0, 1]
#     5       0.256164302315867  [0, 1]
#
# Mean RMSE for Validaton Data: 0.2807374907631652
# Median RMSE for Validaton Data: 0.2561643023158674
#
# -------
#
# Model for these predictors: 'day_index', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.894092287040838  0.187185078079833  [0, 2]
#     2               0.242546581329594  0.195143144174093  [0, 2]
#     3               0.968897090788245  0.183305126177038  [0, 2]
#     4               0.211283409174114  0.194132268521825  [0, 2]
#     5               0.884570249035548  0.199009122125841  [0, 2]
#
# Mean RMSE for "Linear Regression Model": 0.6402779234736677
# Median RMSE for "Linear Regression Model": 0.8845702490355477
# Mean RMSE for "Mean Model": 0.19175494781572605
# Median RMSE for "Mean Model": 0.19413226852182536
#
# Validate for these predictors: 'day_index', 'year'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.856471608745186  [0, 2]
#     2       0.225962766516751  [0, 2]
#     3       0.949101389763103  [0, 2]
#     4       0.2013316644462    [0, 2]
#     5       0.855905235005531  [0, 2]
#
# Mean RMSE for Validaton Data: 0.6177545328953543
# Median RMSE for Validaton Data: 0.8559052350055314
#
# -------
#
# Model for these predictors: 'day_index', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.281725171346156  0.183106129029714  [0, 3]
#     2               0.193574887614555  0.178634976833341  [0, 3]
#     3               0.67792082448418   0.186122183933818  [0, 3]
#     4               0.468569463243093  0.191878309054734  [0, 3]
#     5               1.00077899284663   0.19216321758422   [0, 3]
#
# Mean RMSE for "Linear Regression Model": 0.5245138679069218
# Median RMSE for "Linear Regression Model": 0.46856946324309273
# Mean RMSE for "Mean Model": 0.18638096328716536
# Median RMSE for "Mean Model": 0.18612218393381805
#
# Validate for these predictors: 'day_index', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.279863614018199  [0, 3]
#     2       0.19521687163025   [0, 3]
#     3       0.658947901111167  [0, 3]
#     4       0.443675576092632  [0, 3]
#     5       0.963829228313551  [0, 3]
#
# Mean RMSE for Validaton Data: 0.50830663823316
# Median RMSE for Validaton Data: 0.44367557609263203
#
# -------
#
# Model for these predictors: 'day_index', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               1.50832655516441   0.182656105551278  [0, 4]
#     2               0.20444244883826   0.186688840954054  [0, 4]
#     3               0.223292182767331  0.180919553365181  [0, 4]
#     4               0.231369272677467  0.183636618077483  [0, 4]
#     5               0.204077041390521  0.183153623006856  [0, 4]
#
# Mean RMSE for "Linear Regression Model": 0.4743015001675988
# Median RMSE for "Linear Regression Model": 0.22329218276733082
# Mean RMSE for "Mean Model": 0.18341094819097045
# Median RMSE for "Mean Model": 0.18315362300685614
#
# Validate for these predictors: 'day_index', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       1.39913043280049   [0, 4]
#     2       0.225775397908581  [0, 4]
#     3       0.20672087974278   [0, 4]
#     4       0.22280571607912   [0, 4]
#     5       0.129216503715591  [0, 4]
#
# Mean RMSE for Validaton Data: 0.43672978604931234
# Median RMSE for Validaton Data: 0.22280571607912017
#
# -------
#
# Model for these predictors: 'day_index', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.202221936640866  0.189147996416824  [0, 5]
#     2               0.194992948832446  0.191732742851919  [0, 5]
#     3               0.200759614113223  0.184263371273838  [0, 5]
#     4               0.197895129452359  0.191033976447808  [0, 5]
#     5               0.563966442089104  0.179709002838341  [0, 5]
#
# Mean RMSE for "Linear Regression Model": 0.2719672142255996
# Median RMSE for "Linear Regression Model": 0.20075961411322335
# Mean RMSE for "Mean Model": 0.1871774179657461
# Median RMSE for "Mean Model": 0.18914799641682442
#
# Validate for these predictors: 'day_index', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.179521330178429  [0, 5]
#     2       0.189672798361952  [0, 5]
#     3       0.192164325320854  [0, 5]
#     4       0.202768735535037  [0, 5]
#     5       0.549248172119246  [0, 5]
#
# Mean RMSE for Validaton Data: 0.26267507230310344
# Median RMSE for Validaton Data: 0.19216432532085378
#
# -------
#
# Model for these predictors: 'day_index', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.91136392873436   0.170233495508776  [0, 6]
#     2               0.190642448276845  0.188599765273946  [0, 6]
#     3               0.249743180786334  0.191710390654214  [0, 6]
#     4               0.37242012745124   0.185426055493445  [0, 6]
#     5               0.18587338537533   0.184311181354354  [0, 6]
#
# Mean RMSE for "Linear Regression Model": 0.382008614124822
# Median RMSE for "Linear Regression Model": 0.2497431807863344
# Mean RMSE for "Mean Model": 0.18405617765694698
# Median RMSE for "Mean Model": 0.18542605549344524
#
# Validate for these predictors: 'day_index', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.806160540727978  [0, 6]
#     2       0.181412986610235  [0, 6]
#     3       0.245978892772237  [0, 6]
#     4       0.333646648822463  [0, 6]
#     5       0.174264602090488  [0, 6]
#
# Mean RMSE for Validaton Data: 0.3482927342046803
# Median RMSE for Validaton Data: 0.2459788927722374
#
# -------
#
# Model for these predictors: 'day', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.235033475483474  0.183186884669972  [1, 2]
#     2               0.508944465756627  0.190262389062691  [1, 2]
#     3               0.389275530136489  0.186416171943591  [1, 2]
#     4               0.193703156019943  0.183780191107013  [1, 2]
#     5               0.344684169206901  0.188064522882897  [1, 2]
#
# Mean RMSE for "Linear Regression Model": 0.33432815932068694
# Median RMSE for "Linear Regression Model": 0.34468416920690137
# Mean RMSE for "Mean Model": 0.18634203193323287
# Median RMSE for "Mean Model": 0.18641617194359128
#
# Validate for these predictors: 'day', 'year'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.243111112588015  [1, 2]
#     2       0.511013575139805  [1, 2]
#     3       0.35699913853434   [1, 2]
#     4       0.196828810938261  [1, 2]
#     5       0.356979709563209  [1, 2]
#
# Mean RMSE for Validaton Data: 0.33298646935272586
# Median RMSE for Validaton Data: 0.35697970956320924
#
# -------
#
# Model for these predictors: 'day', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.203237237818237  0.185937976671666  [1, 3]
#     2               0.202532276527337  0.184289809610369  [1, 3]
#     3               0.198469690262966  0.184679303397859  [1, 3]
#     4               0.204098746754615  0.18959984446899   [1, 3]
#     5               0.201424515033893  0.184183703629272  [1, 3]
#
# Mean RMSE for "Linear Regression Model": 0.20195249327940973
# Median RMSE for "Linear Regression Model": 0.20253227652733727
# Mean RMSE for "Mean Model": 0.18573812755563113
# Median RMSE for "Mean Model": 0.18467930339785923
#
# Validate for these predictors: 'day', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.191784988330846  [1, 3]
#     2       0.23076146474647   [1, 3]
#     3       0.191105726106069  [1, 3]
#     4       0.158260336322197  [1, 3]
#     5       0.201378731518101  [1, 3]
#
# Mean RMSE for Validaton Data: 0.1946582494047368
# Median RMSE for Validaton Data: 0.19178498833084603
#
# -------
#
# Model for these predictors: 'day', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.199665785143326  0.18125427327512   [1, 4]
#     2               0.199279645630273  0.179187605840757  [1, 4]
#     3               0.196085877547108  0.181745575368455  [1, 4]
#     4               0.20213720389929   0.179730732081182  [1, 4]
#     5               0.190833070455869  0.176889484804155  [1, 4]
#
# Mean RMSE for "Linear Regression Model": 0.19760031653517318
# Median RMSE for "Linear Regression Model": 0.19927964563027303
# Mean RMSE for "Mean Model": 0.1797615342739339
# Median RMSE for "Mean Model": 0.17973073208118195
#
# Validate for these predictors: 'day', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.180789694454408  [1, 4]
#     2       0.150085675947107  [1, 4]
#     3       0.212681678894495  [1, 4]
#     4       0.149448942258784  [1, 4]
#     5       0.178742789941328  [1, 4]
#
# Mean RMSE for Validaton Data: 0.17434975629922458
# Median RMSE for Validaton Data: 0.17874278994132828
#
# -------
#
# Model for these predictors: 'day', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.208103771125877  0.190649036677311  [1, 5]
#     2               0.19420339890278   0.184961956430767  [1, 5]
#     3               0.1975419231434    0.186862783850016  [1, 5]
#     4               0.197036266000705  0.187489576814546  [1, 5]
#     5               0.190626048045016  0.181609622102664  [1, 5]
#
# Mean RMSE for "Linear Regression Model": 0.1975022814435557
# Median RMSE for "Linear Regression Model": 0.19703626600070484
# Mean RMSE for "Mean Model": 0.18631459517506077
# Median RMSE for "Mean Model": 0.18686278385001578
#
# Validate for these predictors: 'day', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.183353420560595  [1, 5]
#     2       0.201957957263685  [1, 5]
#     3       0.168690526541971  [1, 5]
#     4       0.170176228423027  [1, 5]
#     5       0.207619947737123  [1, 5]
#
# Mean RMSE for Validaton Data: 0.18635961610528046
# Median RMSE for Validaton Data: 0.18335342056059525
#
# -------
#
# Model for these predictors: 'day', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.199778486329861  0.191903825219602  [1, 6]
#     2               0.199051076205353  0.188969331829422  [1, 6]
#     3               0.188209227458651  0.179990043214755  [1, 6]
#     4               0.199499770284251  0.187471253527536  [1, 6]
#     5               0.201397066755379  0.193847998320454  [1, 6]
#
# Mean RMSE for "Linear Regression Model": 0.19758712540669873
# Median RMSE for "Linear Regression Model": 0.1994997702842505
# Mean RMSE for "Mean Model": 0.18843649042235375
# Median RMSE for "Mean Model": 0.18896933182942197
#
# Validate for these predictors: 'day', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.171891033886709  [1, 6]
#     2       0.153795455213304  [1, 6]
#     3       0.186056794923948  [1, 6]
#     4       0.185661272030703  [1, 6]
#     5       0.147358362591198  [1, 6]
#
# Mean RMSE for Validaton Data: 0.16895258372917224
# Median RMSE for Validaton Data: 0.1718910338867092
#
# -------
#
# Model for these predictors: 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.178676415491608  0.174954763597768  [2, 3]
#     2               0.219252890648824  0.192073287934604  [2, 3]
#     3               1.0808586328809    0.1887376713479    [2, 3]
#     4               0.536478329966904  0.180393939162541  [2, 3]
#     5               1.05222003032693   0.18651306108222   [2, 3]
#
# Mean RMSE for "Linear Regression Model": 0.613497259863034
# Median RMSE for "Linear Regression Model": 0.5364783299669045
# Mean RMSE for "Mean Model": 0.1845345446250067
# Median RMSE for "Mean Model": 0.18651306108222004
#
# Validate for these predictors: 'year', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.185371860107238  [2, 3]
#     2       0.196088689368824  [2, 3]
#     3       1.07219594131155   [2, 3]
#     4       0.546316418587751  [2, 3]
#     5       1.062601175669     [2, 3]
#
# Mean RMSE for Validaton Data: 0.6125148170088732
# Median RMSE for Validaton Data: 0.5463164185877515
#
# -------
#
# Model for these predictors: 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.736130253047101  0.185447248132341  [2, 4]
#     2               0.523540688806259  0.191166197228993  [2, 4]
#     3               0.202737211742239  0.185732923569855  [2, 4]
#     4               0.213502169595583  0.180254135923667  [2, 4]
#     5               0.719819959767941  0.190202759645109  [2, 4]
#
# Mean RMSE for "Linear Regression Model": 0.4791460565918248
# Median RMSE for "Linear Regression Model": 0.5235406888062591
# Mean RMSE for "Mean Model": 0.18656065289999293
# Median RMSE for "Mean Model": 0.18573292356985513
#
# Validate for these predictors: 'year', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.725098327828667  [2, 4]
#     2       0.52727717592658   [2, 4]
#     3       0.172428384717409  [2, 4]
#     4       0.215579117204539  [2, 4]
#     5       0.721687533428046  [2, 4]
#
# Mean RMSE for Validaton Data: 0.4724141078210482
# Median RMSE for Validaton Data: 0.52727717592658
#
# -------
#
# Model for these predictors: 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               1.22475737451118   0.192684392376843  [2, 5]
#     2               0.240798813490247  0.188457976210901  [2, 5]
#     3               0.566119673864365  0.180360683759021  [2, 5]
#     4               0.295973778968051  0.178267252220736  [2, 5]
#     5               0.675578263546909  0.188700010447343  [2, 5]
#
# Mean RMSE for "Linear Regression Model": 0.6006455808761496
# Median RMSE for "Linear Regression Model": 0.5661196738643653
# Mean RMSE for "Mean Model": 0.18569406300296862
# Median RMSE for "Mean Model": 0.18845797621090077
#
# Validate for these predictors: 'year', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       1.21278545608907   [2, 5]
#     2       0.222317907047731  [2, 5]
#     3       0.5729227313789    [2, 5]
#     4       0.295475094224062  [2, 5]
#     5       0.682532059880415  [2, 5]
#
# Mean RMSE for Validaton Data: 0.5972066497240363
# Median RMSE for Validaton Data: 0.5729227313788999
#
# -------
#
# Model for these predictors: 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.342032604549064  0.184661776334662  [2, 6]
#     2               0.18801560212452   0.187533960192371  [2, 6]
#     3               0.240731019757442  0.188606181254665  [2, 6]
#     4               0.301378267764711  0.187177143186828  [2, 6]
#     5               0.750867011166458  0.18324684381022   [2, 6]
#
# Mean RMSE for "Linear Regression Model": 0.3646049010724388
# Median RMSE for "Linear Regression Model": 0.301378267764711
# Mean RMSE for "Mean Model": 0.18624518095574943
# Median RMSE for "Mean Model": 0.18717714318682835
#
# Validate for these predictors: 'year', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.346224999674188  [2, 6]
#     2       0.175178483475313  [2, 6]
#     3       0.232158853814617  [2, 6]
#     4       0.28334031817082   [2, 6]
#     5       0.755768607494561  [2, 6]
#
# Mean RMSE for Validaton Data: 0.3585342525258999
# Median RMSE for Validaton Data: 0.28334031817081984
#
# -------
#
# Model for these predictors: 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.19908300041994   0.185674052138111  [3, 4]
#     2               0.20289278806632   0.193234904162421  [3, 4]
#     3               0.192830196047781  0.186561652832001  [3, 4]
#     4               0.200475751431677  0.191316515159087  [3, 4]
#     5               0.200704843246359  0.187421115824718  [3, 4]
#
# Mean RMSE for "Linear Regression Model": 0.19919731584241535
# Median RMSE for "Linear Regression Model": 0.20047575143167706
# Mean RMSE for "Mean Model": 0.18884164802326736
# Median RMSE for "Mean Model": 0.18742111582471765
#
# Validate for these predictors: 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.189006421344499  [3, 4]
#     2       0.190656406016856  [3, 4]
#     3       0.199560378713994  [3, 4]
#     4       0.186713363283748  [3, 4]
#     5       0.181223812135018  [3, 4]
#
# Mean RMSE for Validaton Data: 0.18943207629882297
# Median RMSE for Validaton Data: 0.18900642134449858
#
# -------
#
# Model for these predictors: 'mo', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.193287004704316  0.186451154631269  [3, 5]
#     2               0.183267291526339  0.178928304344868  [3, 5]
#     3               0.18878879509369   0.186359656599815  [3, 5]
#     4               0.198491925075879  0.187782456780744  [3, 5]
#     5               0.19331911798789   0.185944259106426  [3, 5]
#
# Mean RMSE for "Linear Regression Model": 0.19143082687762272
# Median RMSE for "Linear Regression Model": 0.19328700470431617
# Mean RMSE for "Mean Model": 0.18509316629262426
# Median RMSE for "Mean Model": 0.18635965659981485
#
# Validate for these predictors: 'mo', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.170114288783559  [3, 5]
#     2       0.174252666901654  [3, 5]
#     3       0.188394820211229  [3, 5]
#     4       0.180557032389552  [3, 5]
#     5       0.173382217992978  [3, 5]
#
# Mean RMSE for Validaton Data: 0.17734020525579433
# Median RMSE for Validaton Data: 0.17425266690165414
#
# -------
#
# Model for these predictors: 'mo', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.19858348793191   0.180406813775036  [3, 6]
#     2               0.187541627242444  0.182815470216955  [3, 6]
#     3               0.193420370567637  0.189288414726189  [3, 6]
#     4               0.194782619640866  0.187152732593883  [3, 6]
#     5               0.200654547865282  0.187391772625501  [3, 6]
#
# Mean RMSE for "Linear Regression Model": 0.1949965306496279
# Median RMSE for "Linear Regression Model": 0.19478261964086638
# Mean RMSE for "Mean Model": 0.18541104078751275
# Median RMSE for "Mean Model": 0.18715273259388288
#
# Validate for these predictors: 'mo', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.18348798125261   [3, 6]
#     2       0.172630014585845  [3, 6]
#     3       0.155938862400262  [3, 6]
#     4       0.168918363465587  [3, 6]
#     5       0.198351640616655  [3, 6]
#
# Mean RMSE for Validaton Data: 0.1758653724641918
# Median RMSE for Validaton Data: 0.1726300145858448
#
# -------
#
# Model for these predictors: 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.19461708050561   0.189419191888221  [4, 5]
#     2               0.188525866852613  0.182322550110414  [4, 5]
#     3               0.194106786598107  0.187190937451167  [4, 5]
#     4               0.195567756012863  0.189604769837251  [4, 5]
#     5               0.19097623673443   0.187695507724267  [4, 5]
#
# Mean RMSE for "Linear Regression Model": 0.19275874534072504
# Median RMSE for "Linear Regression Model": 0.19410678659810737
# Mean RMSE for "Mean Model": 0.18724659140226405
# Median RMSE for "Mean Model": 0.1876955077242666
#
# Validate for these predictors: 'temp', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.159687610000326  [4, 5]
#     2       0.170326616096171  [4, 5]
#     3       0.184980942199428  [4, 5]
#     4       0.169838493360417  [4, 5]
#     5       0.172549593276917  [4, 5]
#
# Mean RMSE for Validaton Data: 0.17147665098665202
# Median RMSE for Validaton Data: 0.17032661609617097
#
# -------
#
# Model for these predictors: 'temp', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.187661227989886  0.182786230390377  [4, 6]
#     2               0.201022741799609  0.193136347897371  [4, 6]
#     3               0.187302153150789  0.182048168252775  [4, 6]
#     4               0.208638819652692  0.187126200814487  [4, 6]
#     5               0.198171138085874  0.191008448372707  [4, 6]
#
# Mean RMSE for "Linear Regression Model": 0.19655921613576993
# Median RMSE for "Linear Regression Model": 0.19817113808587442
# Mean RMSE for "Mean Model": 0.18722107914554353
# Median RMSE for "Mean Model": 0.18712620081448694
#
# Validate for these predictors: 'temp', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.180547599067996  [4, 6]
#     2       0.199177391710084  [4, 6]
#     3       0.186442413683178  [4, 6]
#     4       0.172850510128049  [4, 6]
#     5       0.150538190614397  [4, 6]
#
# Mean RMSE for Validaton Data: 0.17791122104074092
# Median RMSE for Validaton Data: 0.1805475990679964
#
# -------
#
# Model for these predictors: 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.182063619688556  0.17870335977513   [5, 6]
#     2               0.185961573150501  0.179894936409094  [5, 6]
#     3               0.189964416066473  0.183686547164601  [5, 6]
#     4               0.18246082583323   0.176948694038089  [5, 6]
#     5               0.194198235995689  0.194049100093018  [5, 6]
#
# Mean RMSE for "Linear Regression Model": 0.18692973414689
# Median RMSE for "Linear Regression Model": 0.18596157315050135
# Mean RMSE for "Mean Model": 0.1826565274959863
# Median RMSE for "Mean Model": 0.17989493640909418
#
# Validate for these predictors: 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.17392245159311   [5, 6]
#     2       0.18460259433911   [5, 6]
#     3       0.182894126782365  [5, 6]
#     4       0.164186928357402  [5, 6]
#     5       0.172221083717708  [5, 6]
#
# Mean RMSE for Validaton Data: 0.17556543695793925
# Median RMSE for Validaton Data: 0.17392245159311012
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'year'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.615000141319414  0.177786779132555  [0, 1, 2]
#     2               0.226312949778547  0.190015903277713  [0, 1, 2]
#     3               1.5346684749705    0.178293919032965  [0, 1, 2]
#     4               0.243437378449617  0.191254032312671  [0, 1, 2]
#     5               0.264075373559557  0.191572306504837  [0, 1, 2]
#
# Mean RMSE for "Linear Regression Model": 0.5766988636155281
# Median RMSE for "Linear Regression Model": 0.2640753735595573
# Mean RMSE for "Mean Model": 0.185784588052148
# Median RMSE for "Mean Model": 0.19001590327771278
#
# Validate for these predictors: 'day_index', 'day', 'year'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.599187009888584  [0, 1, 2]
#     2       0.209758394551372  [0, 1, 2]
#     3       1.41489238433424   [0, 1, 2]
#     4       0.23509937318708   [0, 1, 2]
#     5       0.311167074829824  [0, 1, 2]
#
# Mean RMSE for Validaton Data: 0.5540208473582207
# Median RMSE for Validaton Data: 0.31116707482982425
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.203298951031659  0.185875833460844  [0, 1, 3]
#     2               0.216673057686227  0.182234793801327  [0, 1, 3]
#     3               0.289014438691186  0.19029962892763   [0, 1, 3]
#     4               0.291785183002616  0.188756815726869  [0, 1, 3]
#     5               0.249652393969135  0.18339737798522   [0, 1, 3]
#
# Mean RMSE for "Linear Regression Model": 0.2500848048761646
# Median RMSE for "Linear Regression Model": 0.24965239396913474
# Mean RMSE for "Mean Model": 0.18611288998037784
# Median RMSE for "Mean Model": 0.18587583346084435
#
# Validate for these predictors: 'day_index', 'day', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.18512829584376   [0, 1, 3]
#     2       0.202219614858499  [0, 1, 3]
#     3       0.281564418014973  [0, 1, 3]
#     4       0.241657204721853  [0, 1, 3]
#     5       0.25538498704004   [0, 1, 3]
#
# Mean RMSE for Validaton Data: 0.2331909040958248
# Median RMSE for Validaton Data: 0.24165720472185262
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.283961833989187  0.186272111297805  [0, 1, 4]
#     2               0.478144406755049  0.193495901833604  [0, 1, 4]
#     3               0.20519994962273   0.179048332929286  [0, 1, 4]
#     4               0.212714794878721  0.195156120027946  [0, 1, 4]
#     5               0.214299622891807  0.195700863160889  [0, 1, 4]
#
# Mean RMSE for "Linear Regression Model": 0.27886412162749896
# Median RMSE for "Linear Regression Model": 0.21429962289180735
# Mean RMSE for "Mean Model": 0.18993466584990593
# Median RMSE for "Mean Model": 0.19349590183360427
#
# Validate for these predictors: 'day_index', 'day', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.282154117275399  [0, 1, 4]
#     2       0.466913305119357  [0, 1, 4]
#     3       0.195290084067777  [0, 1, 4]
#     4       0.230127870864856  [0, 1, 4]
#     5       0.209581395533941  [0, 1, 4]
#
# Mean RMSE for Validaton Data: 0.27681335457226613
# Median RMSE for Validaton Data: 0.23012787086485625
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.556248151425575  0.195678713984184  [0, 1, 5]
#     2               0.228284242495808  0.183906185279666  [0, 1, 5]
#     3               0.212216725451936  0.191765263777234  [0, 1, 5]
#     4               0.197806160467269  0.182917843412265  [0, 1, 5]
#     5               0.692279306817307  0.174374322222828  [0, 1, 5]
#
# Mean RMSE for "Linear Regression Model": 0.3773669173315789
# Median RMSE for "Linear Regression Model": 0.22828424249580753
# Mean RMSE for "Mean Model": 0.18572846573523538
# Median RMSE for "Mean Model": 0.18390618527966623
#
# Validate for these predictors: 'day_index', 'day', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.441314567397925  [0, 1, 5]
#     2       0.211262984564242  [0, 1, 5]
#     3       0.193607409177371  [0, 1, 5]
#     4       0.178608118942896  [0, 1, 5]
#     5       0.6554926510387    [0, 1, 5]
#
# Mean RMSE for Validaton Data: 0.3360571462242268
# Median RMSE for Validaton Data: 0.21126298456424228
#
# -------
#
# Model for these predictors: 'day_index', 'day', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.227573409032143  0.183927449512915  [0, 1, 6]
#     2               0.216730917654028  0.190184600722255  [0, 1, 6]
#     3               0.273241758019188  0.192319302243131  [0, 1, 6]
#     4               1.2242058334007    0.176435003541476  [0, 1, 6]
#     5               0.214048989930733  0.186943040343403  [0, 1, 6]
#
# Mean RMSE for "Linear Regression Model": 0.43116018160735836
# Median RMSE for "Linear Regression Model": 0.22757340903214318
# Mean RMSE for "Mean Model": 0.18596187927263597
# Median RMSE for "Mean Model": 0.18694304034340292
#
# Validate for these predictors: 'day_index', 'day', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.206472619728202  [0, 1, 6]
#     2       0.216323336289725  [0, 1, 6]
#     3       0.250841017766085  [0, 1, 6]
#     4       1.09828243144204   [0, 1, 6]
#     5       0.168096537737669  [0, 1, 6]
#
# Mean RMSE for Validaton Data: 0.388003188592744
# Median RMSE for Validaton Data: 0.21632333628972492
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'mo'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.996240613718172  0.183293189020231  [0, 2, 3]
#     2               0.1901538406492    0.18931852651653   [0, 2, 3]
#     3               0.426301656911226  0.182702407933105  [0, 2, 3]
#     4               0.839013860226925  0.180230255043354  [0, 2, 3]
#     5               0.923035178902254  0.182024372280746  [0, 2, 3]
#
# Mean RMSE for "Linear Regression Model": 0.6749490300815553
# Median RMSE for "Linear Regression Model": 0.8390138602269251
# Mean RMSE for "Mean Model": 0.18351375015879318
# Median RMSE for "Mean Model": 0.18270240793310508
#
# Validate for these predictors: 'day_index', 'year', 'mo'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.993757055543353  [0, 2, 3]
#     2       0.176461908670577  [0, 2, 3]
#     3       0.41343511014697   [0, 2, 3]
#     4       0.830650111945073  [0, 2, 3]
#     5       0.925209430723163  [0, 2, 3]
#
# Mean RMSE for Validaton Data: 0.6679027234058269
# Median RMSE for Validaton Data: 0.8306501119450727
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.603812105111025  0.190406544863954  [0, 2, 4]
#     2               0.892086469600404  0.185399758901548  [0, 2, 4]
#     3               0.19669508916538   0.190881915421453  [0, 2, 4]
#     4               0.720080445478992  0.18316190500368   [0, 2, 4]
#     5               0.438754114770319  0.188993652310776  [0, 2, 4]
#
# Mean RMSE for "Linear Regression Model": 0.570285644825224
# Median RMSE for "Linear Regression Model": 0.6038121051110246
# Mean RMSE for "Mean Model": 0.18776875530028206
# Median RMSE for "Mean Model": 0.18899365231077567
#
# Validate for these predictors: 'day_index', 'year', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.623686307246108  [0, 2, 4]
#     2       0.872778647209174  [0, 2, 4]
#     3       0.148939486008012  [0, 2, 4]
#     4       0.726468732700313  [0, 2, 4]
#     5       0.421705758551643  [0, 2, 4]
#
# Mean RMSE for Validaton Data: 0.5587157863430499
# Median RMSE for Validaton Data: 0.6236863072461084
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.4464150208683    0.182806990020553  [0, 2, 5]
#     2               0.203412490233853  0.187837795648133  [0, 2, 5]
#     3               0.271847994271941  0.184044989994097  [0, 2, 5]
#     4               0.779175107604547  0.185355036548081  [0, 2, 5]
#     5               0.201015916747502  0.194702991259431  [0, 2, 5]
#
# Mean RMSE for "Linear Regression Model": 0.38037330594522867
# Median RMSE for "Linear Regression Model": 0.2718479942719412
# Mean RMSE for "Mean Model": 0.18694956069405916
# Median RMSE for "Mean Model": 0.18535503654808103
#
# Validate for these predictors: 'day_index', 'year', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.416000647832266  [0, 2, 5]
#     2       0.170601285425041  [0, 2, 5]
#     3       0.273731480335242  [0, 2, 5]
#     4       0.748891925959118  [0, 2, 5]
#     5       0.167537154667032  [0, 2, 5]
#
# Mean RMSE for Validaton Data: 0.3553524988437399
# Median RMSE for Validaton Data: 0.27373148033524214
#
# -------
#
# Model for these predictors: 'day_index', 'year', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.290660972527193  0.195161077393477  [0, 2, 6]
#     2               0.607463680749419  0.191741805691078  [0, 2, 6]
#     3               0.296904184805319  0.19056752496525   [0, 2, 6]
#     4               1.59036720531122   0.189482075666717  [0, 2, 6]
#     5               0.380206910815368  0.188119432709549  [0, 2, 6]
#
# Mean RMSE for "Linear Regression Model": 0.6331205908417039
# Median RMSE for "Linear Regression Model": 0.3802069108153677
# Mean RMSE for "Mean Model": 0.1910143832852144
# Median RMSE for "Mean Model": 0.19056752496524998
#
# Validate for these predictors: 'day_index', 'year', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.255943514416054  [0, 2, 6]
#     2       0.589800234582612  [0, 2, 6]
#     3       0.254231410239163  [0, 2, 6]
# ...
#
# Mean RMSE for "Linear Regression Model": 0.2421913551897148
# Median RMSE for "Linear Regression Model": 0.24884477532991903
# Mean RMSE for "Mean Model": 0.1877588080023037
# Median RMSE for "Mean Model": 0.18821365026407977
#
# Validate for these predictors: 'day_index', 'mo', 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.215237202947669  [0, 3, 5, 6]
#     2       0.214948155840956  [0, 3, 5, 6]
#     3       0.27082128883674   [0, 3, 5, 6]
#     4       0.188802633591223  [0, 3, 5, 6]
#     5       0.248362896690972  [0, 3, 5, 6]
#
# Mean RMSE for Validaton Data: 0.22763443558151203
# Median RMSE for Validaton Data: 0.21523720294766893
#
# -------
#
# Model for these predictors: 'day_index', 'temp', 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.202931000944268  0.189475785114009  [0, 4, 5, 6]
#     2               0.212327750561169  0.179922153170181  [0, 4, 5, 6]
#     3               0.839816015336292  0.183844827764215  [0, 4, 5, 6]
#     4               0.286202045650809  0.187334825605628  [0, 4, 5, 6]
#     5               0.647075728881759  0.186570627756132  [0, 4, 5, 6]
#
# Mean RMSE for "Linear Regression Model": 0.4376705082748596
# Median RMSE for "Linear Regression Model": 0.28620204565080937
# Mean RMSE for "Mean Model": 0.18542964388203287
# Median RMSE for "Mean Model": 0.18657062775613215
#
# Validate for these predictors: 'day_index', 'temp', 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.180309842711414  [0, 4, 5, 6]
#     2       0.196582074641895  [0, 4, 5, 6]
#     3       0.850466224439437  [0, 4, 5, 6]
#     4       0.293840153795338  [0, 4, 5, 6]
#     5       0.613731416155238  [0, 4, 5, 6]
#
# Mean RMSE for Validaton Data: 0.42698594234866444
# Median RMSE for Validaton Data: 0.2938401537953383
#
# -------
#
# Model for these predictors: 'day', 'year', 'mo', 'temp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.751859108607958  0.190412922803523  [1, 2, 3, 4]
#     2               1.07248175138096   0.183474159249033  [1, 2, 3, 4]
#     3               0.587012601641142  0.179498502216978  [1, 2, 3, 4]
#     4               0.348008493807866  0.190899966965567  [1, 2, 3, 4]
#     5               0.221582171850929  0.179657521583704  [1, 2, 3, 4]
#
# Mean RMSE for "Linear Regression Model": 0.5961888254577707
# Median RMSE for "Linear Regression Model": 0.5870126016411423
# Mean RMSE for "Mean Model": 0.18478861456376086
# Median RMSE for "Mean Model": 0.1834741592490326
#
# Validate for these predictors: 'day', 'year', 'mo', 'temp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.75173451637767   [1, 2, 3, 4]
#     2       1.06272189863253   [1, 2, 3, 4]
#     3       0.588821784226597  [1, 2, 3, 4]
#     4       0.33537423624044   [1, 2, 3, 4]
#     5       0.227152330878223  [1, 2, 3, 4]
#
# Mean RMSE for Validaton Data: 0.5931609532710915
# Median RMSE for Validaton Data: 0.5888217842265971
#
# -------
#
# Model for these predictors: 'day', 'year', 'mo', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.488432101328837  0.181171494796296  [1, 2, 3, 5]
#     2               1.1858709259509    0.188479340911038  [1, 2, 3, 5]
#     3               0.199191809921488  0.179231168237547  [1, 2, 3, 5]
#     4               0.347600746684119  0.18395195151404   [1, 2, 3, 5]
#     5               0.737610988371852  0.186483381327331  [1, 2, 3, 5]
#
# Mean RMSE for "Linear Regression Model": 0.5917413144514383
# Median RMSE for "Linear Regression Model": 0.4884321013288366
# Mean RMSE for "Mean Model": 0.18386346735725026
# Median RMSE for "Mean Model": 0.18395195151403967
#
# Validate for these predictors: 'day', 'year', 'mo', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.468433472515445  [1, 2, 3, 5]
#     2       1.19547402043407   [1, 2, 3, 5]
#     3       0.205720983079194  [1, 2, 3, 5]
#     4       0.329822992676268  [1, 2, 3, 5]
#     5       0.731543738497765  [1, 2, 3, 5]
#
# Mean RMSE for Validaton Data: 0.5861990414405495
# Median RMSE for Validaton Data: 0.46843347251544465
#
# -------
#
# Model for these predictors: 'day', 'year', 'mo', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.510910178443696  0.184875118973625  [1, 2, 3, 6]
#     2               0.255483351712922  0.182406651853069  [1, 2, 3, 6]
#     3               0.196937683619029  0.18461276007536   [1, 2, 3, 6]
#     4               0.256130510936104  0.18416284432219   [1, 2, 3, 6]
#     5               0.630800840513514  0.180452677485234  [1, 2, 3, 6]
#
# Mean RMSE for "Linear Regression Model": 0.37005251304505304
# Median RMSE for "Linear Regression Model": 0.2561305109361042
# Mean RMSE for "Mean Model": 0.1833020105418956
# Median RMSE for "Mean Model": 0.18416284432219046
#
# Validate for these predictors: 'day', 'year', 'mo', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.514426711491842  [1, 2, 3, 6]
#     2       0.260007951498122  [1, 2, 3, 6]
#     3       0.178506771838926  [1, 2, 3, 6]
#     4       0.239492926188768  [1, 2, 3, 6]
#     5       0.606212090376967  [1, 2, 3, 6]
#
# Mean RMSE for Validaton Data: 0.3597292902789251
# Median RMSE for Validaton Data: 0.26000795149812184
#
# -------
#
# Model for these predictors: 'day', 'year', 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.852764115158624  0.197688376252425  [1, 2, 4, 5]
#     2               0.404755317447517  0.192579765206939  [1, 2, 4, 5]
#     3               0.198793719861858  0.182652723983809  [1, 2, 4, 5]
#     4               0.192405443843532  0.178834697253372  [1, 2, 4, 5]
#     5               0.246326051857764  0.187870435931831  [1, 2, 4, 5]
#
# Mean RMSE for "Linear Regression Model": 0.37900892963385874
# Median RMSE for "Linear Regression Model": 0.24632605185776357
# Mean RMSE for "Mean Model": 0.18792519972567528
# Median RMSE for "Mean Model": 0.18787043593183075
#
# Validate for these predictors: 'day', 'year', 'temp', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.828017644175262  [1, 2, 4, 5]
#     2       0.402765358139272  [1, 2, 4, 5]
#     3       0.20407020498862   [1, 2, 4, 5]
#     4       0.199269729683095  [1, 2, 4, 5]
#     5       0.219556362466549  [1, 2, 4, 5]
#
# Mean RMSE for Validaton Data: 0.3707358598905598
# Median RMSE for Validaton Data: 0.21955636246654947
#
# -------
#
# Model for these predictors: 'day', 'year', 'temp', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.841518931596981  0.179994117635976  [1, 2, 4, 6]
#     2               0.713206088972788  0.183896369883042  [1, 2, 4, 6]
#     3               0.357622507816199  0.187006849149017  [1, 2, 4, 6]
#     4               0.388076750131502  0.176158915175621  [1, 2, 4, 6]
#     5               0.208815755806629  0.18750178756615   [1, 2, 4, 6]
#
# Mean RMSE for "Linear Regression Model": 0.5018480068648199
# Median RMSE for "Linear Regression Model": 0.3880767501315017
# Mean RMSE for "Mean Model": 0.18291160788196104
# Median RMSE for "Mean Model": 0.1838963698830415
#
# Validate for these predictors: 'day', 'year', 'temp', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.828095787728491  [1, 2, 4, 6]
#     2       0.697996714608195  [1, 2, 4, 6]
#     3       0.346889100156818  [1, 2, 4, 6]
#     4       0.379974675073178  [1, 2, 4, 6]
#     5       0.155867262628087  [1, 2, 4, 6]
#
# Mean RMSE for Validaton Data: 0.48176470803895366
# Median RMSE for Validaton Data: 0.3799746750731778
#
# -------
#
# Model for these predictors: 'day', 'year', 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.191947474950677  0.179781139362394  [1, 2, 5, 6]
#     2               0.693751553803162  0.193841771050058  [1, 2, 5, 6]
#     3               0.257952203329809  0.190636456604752  [1, 2, 5, 6]
#     4               0.452895422248284  0.189847275286197  [1, 2, 5, 6]
#     5               0.790568151129222  0.182588900036702  [1, 2, 5, 6]
#
# Mean RMSE for "Linear Regression Model": 0.47742296109223065
# Median RMSE for "Linear Regression Model": 0.45289542224828394
# Mean RMSE for "Mean Model": 0.1873391084680206
# Median RMSE for "Mean Model": 0.18984727528619721
#
# Validate for these predictors: 'day', 'year', 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.15781668843733   [1, 2, 5, 6]
#     2       0.692570442174491  [1, 2, 5, 6]
#     3       0.228236346144708  [1, 2, 5, 6]
#     4       0.45739454800604   [1, 2, 5, 6]
#     5       0.777094813695965  [1, 2, 5, 6]
#
# Mean RMSE for Validaton Data: 0.4626225676917068
# Median RMSE for Validaton Data: 0.4573945480060395
#
# -------
#
# Model for these predictors: 'day', 'mo', 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.204552965395295  0.192004350109615  [1, 3, 4, 5]
#     2               0.200718301500307  0.185463652775256  [1, 3, 4, 5]
#     3               0.207999969096923  0.186013654565026  [1, 3, 4, 5]
#     4               0.209336605499705  0.187275530147435  [1, 3, 4, 5]
#     5               0.209149558319176  0.194775078423338  [1, 3, 4, 5]
#
# Mean RMSE for "Linear Regression Model": 0.20635147996228137
# Median RMSE for "Linear Regression Model": 0.207999969096923
# Mean RMSE for "Mean Model": 0.18910645320413416
# Median RMSE for "Mean Model": 0.1872755301474354
#
# Validate for these predictors: 'day', 'mo', 'temp', 'visib'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.167272349574188  [1, 3, 4, 5]
#     2       0.206545762263923  [1, 3, 4, 5]
#     3       0.204079509063325  [1, 3, 4, 5]
#     4       0.173245165306316  [1, 3, 4, 5]
#     5       0.195553140555572  [1, 3, 4, 5]
#
# Mean RMSE for Validaton Data: 0.1893391853526647
# Median RMSE for Validaton Data: 0.19555314055557166
#
# -------
#
# Model for these predictors: 'day', 'mo', 'temp', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.217411911940967  0.189320625861482  [1, 3, 4, 6]
#     2               0.203276863773483  0.182758377667622  [1, 3, 4, 6]
#     3               0.207564819994811  0.19163015595113   [1, 3, 4, 6]
#     4               0.220017492112981  0.190896368163657  [1, 3, 4, 6]
#     5               0.202322229700196  0.188828520649308  [1, 3, 4, 6]
#
# Mean RMSE for "Linear Regression Model": 0.21011866350448768
# Median RMSE for "Linear Regression Model": 0.20756481999481052
# Mean RMSE for "Mean Model": 0.18868680965863988
# Median RMSE for "Mean Model": 0.1893206258614818
#
# Validate for these predictors: 'day', 'mo', 'temp', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.204101998830073  [1, 3, 4, 6]
#     2       0.228036760885175  [1, 3, 4, 6]
#     3       0.195083041702462  [1, 3, 4, 6]
#     4       0.218486312893261  [1, 3, 4, 6]
#     5       0.219767489818751  [1, 3, 4, 6]
#
# Mean RMSE for Validaton Data: 0.21309512082594462
# Median RMSE for Validaton Data: 0.2184863128932609
#
# -------
#
# Model for these predictors: 'day', 'mo', 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.200887121140271  0.18803533120824   [1, 3, 5, 6]
#     2               0.209350562175922  0.19525328909296   [1, 3, 5, 6]
#     3               0.206529885040821  0.191093381520823  [1, 3, 5, 6]
#     4               0.209144437547972  0.188216484431664  [1, 3, 5, 6]
#     5               0.196178628926087  0.181239872131125  [1, 3, 5, 6]
#
# Mean RMSE for "Linear Regression Model": 0.2044181269662148
# Median RMSE for "Linear Regression Model": 0.20652988504082054
# Mean RMSE for "Mean Model": 0.18876767167696246
# Median RMSE for "Mean Model": 0.18821648443166422
#
# Validate for these predictors: 'day', 'mo', 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.194363577987521  [1, 3, 5, 6]
#     2       0.203832504554155  [1, 3, 5, 6]
#     3       0.181543849221005  [1, 3, 5, 6]
#     4       0.168619946229186  [1, 3, 5, 6]
#     5       0.190956986554082  [1, 3, 5, 6]
#
# Mean RMSE for Validaton Data: 0.18786337290918984
# Median RMSE for Validaton Data: 0.19095698655408222
#
# -------
#
# Model for these predictors: 'day', 'temp', 'visib', 'wdsp'
# Model for these targets: 'NUM_COLLISIONS'
#
#   Run    Linear Regression Model RMSE    Mean Model RMSE  Predictors Columns
# -----  ------------------------------  -----------------  --------------------
#     1               0.197646260448812  0.182681574855637  [1, 4, 5, 6]
#     2               0.200139055696737  0.185819278264154  [1, 4, 5, 6]
#     3               0.198085982320394  0.180515999204679  [1, 4, 5, 6]
#     4               0.209622881862415  0.191503357553918  [1, 4, 5, 6]
#     5               0.207178575605551  0.190515794953384  [1, 4, 5, 6]
#
# Mean RMSE for "Linear Regression Model": 0.2025345511867819
# Median RMSE for "Linear Regression Model": 0.20013905569673748
# Mean RMSE for "Mean Model": 0.18620720096635432
# Median RMSE for "Mean Model": 0.18581927826415418
#
# Validate for these predictors: 'day', 'temp', 'visib', 'wdsp'
# Validate for these targets: 'NUM_COLLISIONS'
#
#   Run    Validation Test RMSE  Predictors Columns
# -----  ----------------------  --------------------
#     1       0.163000931481222  [1, 4, 5, 6]
#     2       0.18865105591321   [1, 4, 5, 6]
#     3       0.224925426864799  [1, 4, 5, 6]
#     4       0.198605539207457  [1, 4, 5, 6]
#     5       0.193991004540344  [1, 4, 5, 6]
#
# Mean RMSE for Validaton Data: 0.19383479160140635
# Median RMSE for Validaton Data: 0.19399100454034415
#
# -------
#
# Model for these predictors: 'year', 'mo', 'temp', 'visib'
# Model for these targets: 'NUM_COLLISIONS'

# %%
# print all results in memory from all runs (optional)
print(all_rmse_results)
